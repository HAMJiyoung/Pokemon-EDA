# %% [markdown]
# # 기본 데이터

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
pokemon = pd.read_csv('pokemon_raw.csv')

# %%
pokemon.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...        name  percentage_male  \
# ...

# %%
pokemon.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'defense', 'experience_growth', 'hp', 'name', 'percentage_male',
#        'pokedex_number', 'sp_attack', 'sp_defense', 'speed', 'type1', 'type2',
#        'generation', 'is_legendary'],
#       dtype='object')

# %% [markdown]
# ### 전체 컬럼 중 현재 분석에서 필요 없는 컬럼 삭제

# %%
pokemon = pokemon.drop(columns=['abilities', 'base_egg_steps', 'base_happiness', 'capture_rate', 'experience_growth', 'percentage_male'], axis=1)
pokemon
# Out:
#      against_bug  against_dark  against_dragon  against_electric  \
# 0           1.00           1.0             1.0               0.5
# 1           1.00           1.0             1.0               0.5
# 2           1.00           1.0             1.0               0.5
# 3           0.50           1.0             1.0               1.0
# 4           0.50           1.0             1.0               1.0
# ..           ...           ...             ...               ...
# 796         0.25           1.0             0.5               2.0
# 797         1.00           1.0             0.5               0.5
# 798         2.00           0.5             2.0               0.5
# 799         2.00           2.0             1.0               1.0
# 800         0.25           0.5             0.0               1.0
#
#      against_fairy  against_fight  against_fire  against_flying  \
# 0              0.5            0.5           2.0             2.0
# ...

# %%
pokemon = pokemon.set_index('pokedex_number', drop = True)

# %%
pokemon
# Out:
#                 against_bug  against_dark  against_dragon  against_electric  \
# pokedex_number
# 1                      1.00           1.0             1.0               0.5
# 2                      1.00           1.0             1.0               0.5
# 3                      1.00           1.0             1.0               0.5
# 4                      0.50           1.0             1.0               1.0
# 5                      0.50           1.0             1.0               1.0
# ...                     ...           ...             ...               ...
# 797                    0.25           1.0             0.5               2.0
# 798                    1.00           1.0             0.5               0.5
# 799                    2.00           0.5             2.0               0.5
# 800                    2.00           2.0             1.0               1.0
# 801                    0.25           0.5             0.0               1.0
#
# ...

# %%
pokemon.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count   801.000000    801.000000      801.000000        801.000000
# mean      0.996255      1.057116        0.968789          1.073970
# std       0.597248      0.438142        0.353058          0.654962
# min       0.250000      0.250000        0.000000          0.000000
# 25%       0.500000      1.000000        1.000000          0.500000
# 50%       1.000000      1.000000        1.000000          1.000000
# 75%       1.000000      1.000000        1.000000          1.000000
# max       4.000000      4.000000        2.000000          4.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count     801.000000     801.000000    801.000000      801.000000
# mean        1.068976       1.065543      1.135456        1.192884
# std         0.522167       0.717251      0.691853        0.604488
# min         0.250000       0.000000      0.250000        0.250000
# ...

# %%
pokemon_stat = pokemon.drop(columns=['against_bug', 'against_dark', 'against_dragon', 'against_electric', 'against_fairy', 'against_fight', 'against_fire','against_flying', 'against_ghost', 'against_grass', 'against_ground','against_ice', 'against_normal', 'against_poison', 'against_psychic','against_rock', 'against_steel', 'against_water'], axis=1)
pokemon_stat
# Out:
#                 attack  base_total  defense   hp        name  sp_attack  \
# pokedex_number
# 1                   49         318       49   45   Bulbasaur         65
# 2                   62         405       63   60     Ivysaur         80
# 3                  100         625      123   80    Venusaur        122
# 4                   52         309       43   39  Charmander         60
# 5                   64         405       58   58  Charmeleon         80
# ...                ...         ...      ...  ...         ...        ...
# 797                101         570      103   97  Celesteela        107
# 798                181         570      131   59     Kartana         59
# 799                101         570       53  223    Guzzlord         97
# 800                107         600      101   97    Necrozma        127
# 801                 95         600      115   80    Magearna        130
#
#                 sp_defense  speed    type1   type2  generation  is_legendary
# ...

# %%
#legendary 포켓몬 분리
pokemon_stat_legendary = pokemon_stat[pokemon_stat['is_legendary'] == 1]
pokemon_stat_legendary
# Out:
#                 attack  base_total  defense   hp        name  sp_attack  \
# pokedex_number
# 144                 85         580      100   90    Articuno         95
# 145                 90         580       85   90      Zapdos        125
# 146                100         580       90   90     Moltres        125
# 150                150         780       70  106      Mewtwo        194
# 151                100         600      100  100         Mew        100
# ...                ...         ...      ...  ...         ...        ...
# 797                101         570      103   97  Celesteela        107
# 798                181         570      131   59     Kartana         59
# 799                101         570       53  223    Guzzlord         97
# 800                107         600      101   97    Necrozma        127
# 801                 95         600      115   80    Magearna        130
#
#                 sp_defense  speed     type1   type2  generation  is_legendary
# ...

# %%
pokemon_stat_legendary = pokemon_stat_legendary[['name', 'type1', 'type2', 'base_total', 'attack', 'defense', 'hp', 'sp_attack', 'sp_defense', 'speed', 'generation', 'is_legendary']]
pokemon_stat_legendary
# Out:
#                       name     type1   type2  base_total  attack  defense  \
# pokedex_number
# 144               Articuno       ice  flying         580      85      100
# 145                 Zapdos  electric  flying         580      90       85
# 146                Moltres      fire  flying         580     100       90
# 150                 Mewtwo   psychic    None         780     150       70
# 151                    Mew   psychic    None         600     100      100
# ...                    ...       ...     ...         ...     ...      ...
# 797             Celesteela     steel  flying         570     101      103
# 798                Kartana     grass   steel         570     181      131
# 799               Guzzlord      dark  dragon         570     101       53
# 800               Necrozma   psychic    None         600     107      101
# 801               Magearna     steel   fairy         600      95      115
#
# ...

# %%
(70/801)*100
# Out:
# 8.739076154806492

# %%
pokemon_stat_legendary.value_counts('type1')
# Out:
# type1
# psychic     17
# dragon       7
# steel        6
# water        6
# electric     5
# fire         5
# grass        4
# rock         4
# bug          3
# dark         3
# normal       3
# ground       2
# ice          2
# fairy        1
# flying       1
# ghost        1
# dtype: int64

# %%
pokemon_stat_legendary.value_counts('type2')
# Out:
# type2
# None        25
# flying      10
# fairy        6
# fighting     6
# dragon       4
# psychic      4
# steel        4
# fire         2
# ghost        2
# grass        2
# electric     1
# ground       1
# ice          1
# poison       1
# water        1
# dtype: int64

# %%
sum(pokemon_stat_legendary['type2'] == 'None') / 70
# Out:
# 0.35714285714285715

# %%
pokemon_stat_legendary[pokemon_stat_legendary['type2'] == 'None'].value_counts('type1')
# Out:
# type1
# psychic     10
# water        3
# electric     2
# normal       2
# dark         1
# fairy        1
# fire         1
# flying       1
# ground       1
# ice          1
# rock         1
# steel        1
# dtype: int64

# %% [markdown]
# 풀, 벌레, 고스트, 격투, 독, 드래곤 단일은 없음</br>
# 단일타입 25(약 36%), 타입이 2개인 포켓몬은 45마리(약 64%)</br>
# 단일타입 가장 많은 타입은 psychic

# %%
#non legendary
pokemon_stat_non_legendary = pokemon_stat[pokemon_stat['is_legendary'] == 0]
pokemon_stat_non_legendary
# Out:
#                 attack  base_total  defense  hp        name  sp_attack  \
# pokedex_number
# 1                   49         318       49  45   Bulbasaur         65
# 2                   62         405       63  60     Ivysaur         80
# 3                  100         625      123  80    Venusaur        122
# 4                   52         309       43  39  Charmander         60
# 5                   64         405       58  58  Charmeleon         80
# ...                ...         ...      ...  ..         ...        ...
# 780                 60         485       85  78      Drampa        135
# 781                131         517      100  70    Dhelmise         86
# 782                 55         300       65  45    Jangmo-o         45
# 783                 75         420       90  55    Hakamo-o         65
# 784                110         600      125  75     Kommo-o        100
#
#                 sp_defense  speed   type1     type2  generation  is_legendary
# pokedex_number
# ...

# %%
pokemon_stat_non_legendary = pokemon_stat_non_legendary[['name', 'type1', 'type2', 'base_total', 'attack', 'defense', 'hp', 'sp_attack', 'sp_defense', 'speed', 'generation', 'is_legendary']]
pokemon_stat_non_legendary
# Out:
#                       name   type1     type2  base_total  attack  defense  hp  \
# pokedex_number
# 1                Bulbasaur   grass    poison         318      49       49  45
# 2                  Ivysaur   grass    poison         405      62       63  60
# 3                 Venusaur   grass    poison         625     100      123  80
# 4               Charmander    fire      None         309      52       43  39
# 5               Charmeleon    fire      None         405      64       58  58
# ...                    ...     ...       ...         ...     ...      ...  ..
# 780                 Drampa  normal    dragon         485      60       85  78
# 781               Dhelmise   ghost     grass         517     131      100  70
# 782               Jangmo-o  dragon      None         300      55       65  45
# 783               Hakamo-o  dragon  fighting         420      75       90  55
# 784                Kommo-o  dragon  fighting         600     110      125  75
#
# ...

# %%
pokemon_stat_non_legendary.value_counts('type1')
# Out:
# type1
# water       108
# normal      102
# grass        74
# bug          69
# fire         47
# rock         41
# psychic      36
# electric     34
# poison       32
# ground       30
# fighting     28
# ghost        26
# dark         26
# ice          21
# dragon       20
# steel        18
# fairy        17
# flying        2
# dtype: int64

# %%
pokemon_stat_non_legendary.value_counts('type2')
# Out:
# type2
# None        359
# flying       85
# poison       33
# ground       33
# psychic      25
# fairy        23
# dark         21
# fighting     19
# grass        18
# steel        18
# water        16
# ice          14
# rock         14
# dragon       13
# ghost        12
# fire         11
# electric      8
# bug           5
# normal        4
# dtype: int64

# %%
pokemon_stat_non_legendary[pokemon_stat_non_legendary['type2'] == 'None'].value_counts('type1')
# Out:
# type1
# normal      59
# water       58
# grass       37
# fire        26
# psychic     25
# electric    24
# fighting    22
# bug         18
# fairy       15
# poison      13
# dragon      12
# ice         11
# rock        10
# ghost        9
# ground       9
# dark         8
# steel        3
# dtype: int64

# %%
sum(pokemon_stat_non_legendary['type2'] == 'None')/731
# Out:
# 0.4911080711354309

# %% [markdown]
# 비행 단일타입 없음</br>
# 단일타입 359(약 49%), 타입 2개 372(약 51%)</br>
# 단일타입 가장 많은 타입은 normal

# %%
#레전더리 스탯 가장 높은 포켓몬
pokemon_stat_legendary[pokemon_stat_legendary['base_total'] == pokemon_stat_legendary['base_total'].max()]
# Out:
#                     name    type1   type2  base_total  attack  defense   hp  \
# pokedex_number
# 150               Mewtwo  psychic    None         780     150       70  106
# 384             Rayquaza   dragon  flying         780     180      100  105
#
#                 sp_attack  sp_defense  speed  generation  is_legendary
# pokedex_number
# 150                   194         120    140           1             1
# 384                   180         100    115           3             1

# %%
#논 레전더리 스탯 가장 높은 포켓몬
pokemon_stat_non_legendary[pokemon_stat_non_legendary['base_total'] == pokemon_stat_non_legendary['base_total'].max()]
# Out:
#                      name   type1    type2  base_total  attack  defense   hp  \
# pokedex_number
# 248             Tyranitar    rock     dark         700     164      150  100
# 373             Salamence  dragon   flying         700     145      130   95
# 376             Metagross   steel  psychic         700     145      150   80
# 445              Garchomp  dragon   ground         700     170      115  108
#
#                 sp_attack  sp_defense  speed  generation  is_legendary
# pokedex_number
# 248                    95         120     71           2             0
# 373                   120          90    120           3             0
# 376                   105         110    110           3             0
# 445                   120          95     92           4             0

# %%
#레전더리 스탯 가장 낮은 포켓몬
pokemon_stat_legendary[pokemon_stat_legendary['base_total'] == pokemon_stat_legendary['base_total'].min()]
# Out:
#                   name    type1 type2  base_total  attack  defense  hp  \
# pokedex_number
# 789             Cosmog  psychic  None         200      29       31  43
#
#                 sp_attack  sp_defense  speed  generation  is_legendary
# pokedex_number
# 789                    29          31     37           7             1

# %%
#논 레전더리 스탯 가장 낮은 포켓몬
pokemon_stat_non_legendary[pokemon_stat_non_legendary['base_total'] == pokemon_stat_non_legendary['base_total'].min()]
# Out:
#                    name  type1 type2  base_total  attack  defense  hp  \
# pokedex_number
# 191             Sunkern  grass  None         180      30       30  30
#
#                 sp_attack  sp_defense  speed  generation  is_legendary
# pokedex_number
# 191                    30          30     30           2             0

# %% [markdown]
# ## 가장 강한 포켓몬?
# - legendary: 150번, 384번 total 780
# > 뮤츠, 레쿠쟈는 애초에 잡기부터가 전설급. 하지만 강려크
# - legendary가 아님: 248, 373, 376, 445번 total 700
# > 마기라스, 보만다, 메타그로스, 한카리아스는 실제로 포켓몬고에서 체육관을 점령할 때 많이 등장한다.
#
# ## 가장 약한 포켓몬?
# - legendary: 789번 total 200
# > 코스모그. 처음 들어봄
# - legendary가 아님: 191번 total 180
# > 해너츠. 커여움

# %% [markdown]
# # * 어떤 포켓몬 타입이 가장 강할/약할까?
# ### 포켓몬 게임 시 느낀 바로는 'dragon' 타입이 가장 강할 것이고, 반면에 가장 약한 타입은 'bug' 타입일 것이다.

# %% [markdown]
# ## legendary 포켓몬의 타입별 능력치

# %%
pokemon_stat_avg_legendary = pd.read_csv('stat_avg_legendary.csv')
pokemon_stat_avg_legendary
# Out:
#        type1     total        hp    attack   defense  sp_attack  sp_defense  \
# 0     dragon  706.8571  115.1429  128.5714  107.2857   144.4286    112.1429
# 1     ground  685.0000   94.5000  162.5000  125.0000   127.5000     85.0000
# 2      ghost  680.0000  150.0000  120.0000  100.0000   120.0000    100.0000
# 3      fairy  680.0000  126.0000  131.0000   95.0000   131.0000     98.0000
# 4     normal  663.3333  110.0000  136.0000  106.6667    92.3333    102.3333
# 5      water  630.0000   91.8333   98.6667  101.6667   124.0000    119.1667
# 6       dark  616.6667  139.6667  107.3333   79.3333   121.0000     80.3333
# 7       fire  608.0000   96.4000  109.0000   98.2000   117.0000    102.0000
# 8       rock  607.5000   82.5000  110.5000  111.7500   102.2500    107.7500
# 9      steel  601.6667   91.3333   96.8333  119.5000   108.6667    106.3333
# 10   psychic  588.8235   89.3529   98.2353   94.6471   105.5294    105.3529
# ...

# %%
pokemon_stat_avg_legendary_maxmin = pokemon_stat_avg_legendary[pokemon_stat_avg_legendary['type1'].isin(['dragon', 'electric'])]
pokemon_stat_avg_legendary_maxmin
# Out:
#        type1     total        hp    attack   defense  sp_attack  sp_defense  \
# 0     dragon  706.8571  115.1429  128.5714  107.2857   144.4286    112.1429
# 15  electric  576.0000   82.4000   96.8000   77.2000   130.6000     83.2000
#
#        speed
# 0    99.2857
# 15  105.8000

# %%
pokemon_stat_avg_legendary_maxmin['total'].diff()
# Out:
# 0          NaN
# 15   -130.8571
# Name: total, dtype: float64

# %%
barlist = plt.bar(data = pokemon_stat_avg_legendary, x = 'type1', height = 'total', color = 'grey')
barlist[0].set_color('tab:blue')
barlist[15].set_color('tab:red')
plt.xticks(rotation = 45)

plt.show()

# %% [markdown]
# ## legendary 포켓몬
# - dragon 타입이 가장 강하고, electric 타입이 가장 약했다. 가장 약할 것이라고 예측했던 bug 타입은 electric과 근소한 차이로 두번째로 약한 타입이다.
# - 가장 강한 타입과 가장 약한 타입의 total 차이는 약 131이다.

# %% [markdown]
# ## legendary 포켓몬 능력치 추가 분석

# %%
pokemon_stat_avg_legendary_nontotal = pokemon_stat_avg_legendary.drop('total', axis = 1)
pokemon_stat_avg_legendary_nontotal
# Out:
#                 hp    attack   defense  sp_attack  sp_defense     speed
# type1
# dragon    115.1429  128.5714  107.2857   144.4286    112.1429   99.2857
# ground     94.5000  162.5000  125.0000   127.5000     85.0000   90.5000
# ghost     150.0000  120.0000  100.0000   120.0000    100.0000   90.0000
# fairy     126.0000  131.0000   95.0000   131.0000     98.0000   99.0000
# normal    110.0000  136.0000  106.6667    92.3333    102.3333  116.0000
# water      91.8333   98.6667  101.6667   124.0000    119.1667   94.6667
# dark      139.6667  107.3333   79.3333   121.0000     80.3333   89.0000
# fire       96.4000  109.0000   98.2000   117.0000    102.0000   85.4000
# rock       82.5000  110.5000  111.7500   102.2500    107.7500   92.7500
# steel      91.3333   96.8333  119.5000   108.6667    106.3333   79.0000
# psychic    89.3529   98.2353   94.6471   105.5294    105.3529   95.7059
# ice        85.0000   67.5000  100.0000    97.5000    162.5000   67.5000
# ...

# %%
pokemon_stat_avg_legendary_nontotal.set_index('type1')
# Out:
#                 hp    attack   defense  sp_attack  sp_defense     speed
# type1
# dragon    115.1429  128.5714  107.2857   144.4286    112.1429   99.2857
# ground     94.5000  162.5000  125.0000   127.5000     85.0000   90.5000
# ghost     150.0000  120.0000  100.0000   120.0000    100.0000   90.0000
# fairy     126.0000  131.0000   95.0000   131.0000     98.0000   99.0000
# normal    110.0000  136.0000  106.6667    92.3333    102.3333  116.0000
# water      91.8333   98.6667  101.6667   124.0000    119.1667   94.6667
# dark      139.6667  107.3333   79.3333   121.0000     80.3333   89.0000
# fire       96.4000  109.0000   98.2000   117.0000    102.0000   85.4000
# rock       82.5000  110.5000  111.7500   102.2500    107.7500   92.7500
# steel      91.3333   96.8333  119.5000   108.6667    106.3333   79.0000
# psychic    89.3529   98.2353   94.6471   105.5294    105.3529   95.7059
# ice        85.0000   67.5000  100.0000    97.5000    162.5000   67.5000
# ...

# %%
pokemon_stat_avg_legendary_nontotal = pokemon_stat_avg_legendary_nontotal.set_index('type1')
pokemon_stat_avg_legendary_nontotal
# Out:
#                 hp    attack   defense  sp_attack  sp_defense     speed
# type1
# dragon    115.1429  128.5714  107.2857   144.4286    112.1429   99.2857
# ground     94.5000  162.5000  125.0000   127.5000     85.0000   90.5000
# ghost     150.0000  120.0000  100.0000   120.0000    100.0000   90.0000
# fairy     126.0000  131.0000   95.0000   131.0000     98.0000   99.0000
# normal    110.0000  136.0000  106.6667    92.3333    102.3333  116.0000
# water      91.8333   98.6667  101.6667   124.0000    119.1667   94.6667
# dark      139.6667  107.3333   79.3333   121.0000     80.3333   89.0000
# fire       96.4000  109.0000   98.2000   117.0000    102.0000   85.4000
# rock       82.5000  110.5000  111.7500   102.2500    107.7500   92.7500
# steel      91.3333   96.8333  119.5000   108.6667    106.3333   79.0000
# psychic    89.3529   98.2353   94.6471   105.5294    105.3529   95.7059
# ice        85.0000   67.5000  100.0000    97.5000    162.5000   67.5000
# ...

# %%
pokemon_stat_avg_legendary_nontotal_t = pokemon_stat_avg_legendary_nontotal.T
pokemon_stat_avg_legendary_nontotal_t
# Out:
# type1         dragon  ground  ghost  fairy    normal     water      dark  \
# hp          115.1429    94.5  150.0  126.0  110.0000   91.8333  139.6667
# attack      128.5714   162.5  120.0  131.0  136.0000   98.6667  107.3333
# defense     107.2857   125.0  100.0   95.0  106.6667  101.6667   79.3333
# sp_attack   144.4286   127.5  120.0  131.0   92.3333  124.0000  121.0000
# sp_defense  112.1429    85.0  100.0   98.0  102.3333  119.1667   80.3333
# speed        99.2857    90.5   90.0   99.0  116.0000   94.6667   89.0000
#
# type1        fire    rock     steel   psychic    ice   grass  flying  \
# hp           96.4   82.50   91.3333   89.3529   85.0   80.00    79.0
# attack      109.0  110.50   96.8333   98.2353   67.5  126.00   100.0
# defense      98.2  111.75  119.5000   94.6471  100.0   98.25    80.0
# sp_attack   117.0  102.25  108.6667  105.5294   97.5   88.50   110.0
# sp_defense  102.0  107.75  106.3333  105.3529  162.5   82.50    90.0
# ...

# %%
sns.boxplot(data = pokemon_stat_avg_legendary_nontotal)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### legendary의 능력치 분포
#
# - attack이 타입별로 가장 차이가 많이 난다.
# - defense는 attack과 반대로 가장 밀집되어 있다.
# - sp_defense가 눈에 띄게 높은 타입이 있다.

# %%
fig = plt.figure(figsize=(18,14))

plt.subplot(2, 3, 1)
g01 = plt.bar(data = pokemon_stat_avg_legendary, x = 'type1', height = 'hp', color = 'grey')
g01[2].set_color('tab:blue')
g01[13].set_color('tab:red')
plt.title('hp')
plt.xticks(rotation = 45)

plt.subplot(2, 3, 2)
g02 = plt.bar(data = pokemon_stat_avg_legendary, x = 'type1', height = 'attack', color = 'grey')
g02[1].set_color('tab:blue')
g02[11].set_color('tab:red')
plt.title('attack')
plt.xticks(rotation = 45)

plt.subplot(2, 3, 3)
g03 = plt.bar(data = pokemon_stat_avg_legendary, x = 'type1', height = 'defense', color = 'grey')
g03[1].set_color('tab:blue')
g03[15].set_color('tab:red')
plt.title('defense')
plt.xticks(rotation = 45)

plt.subplot(2, 3, 4)
g04 = plt.bar(data = pokemon_stat_avg_legendary, x = 'type1', height = 'sp_attack', color = 'grey')
g04[0].set_color('tab:blue')
g04[12].set_color('tab:red')
plt.title('sp_attack')
plt.xticks(rotation = 45)

plt.subplot(2, 3, 5)
g05 = plt.bar(data = pokemon_stat_avg_legendary, x = 'type1', height = 'sp_defense', color = 'grey')
g05[11].set_color('tab:blue')
g05[14].set_color('tab:red')
plt.title('sp_defense')
plt.xticks(rotation = 45)

plt.subplot(2, 3, 6)
g06 = plt.bar(data = pokemon_stat_avg_legendary, x = 'type1', height = 'speed', color = 'grey')
g06[13].set_color('tab:blue')
g06[11].set_color('tab:red')
plt.title('speed')
plt.xticks(rotation = 45)

plt.show()

# %% [markdown]
# ### 능력치별 가장 높은 타입
# 1. hp가 가장 높은 타입: ghost
# 2. attack이 가장 높은 타입: ground
# 3. defense가 가장 높은 타입: ground
# 4. sp_attack이 가장 높은 타입: dragon
# 5. sp_defense가 가장 높은 타입: ice
# 6. speed가 가장 높은 타입: flying
#
# dragon 타입은 sp_attack(필살기)이 가장 높고, 다른 능력치 또한 상위 5~6위로 고르게 높은 편임
#
# ground 타입은 일반 공격/방어 시에 꽤나 우세하나, 기타 능력치가 dragon보다 떨어지며 2등에 머무름.
#
#
# ### 능력치별 가장 낮은 타입
# 1. hp가 가장 낮은 타입: flying
# 2. attack이 가장 낮은 타입: ice
# 3. defense가 가장 낮은 타입: electric
# 4. sp_attack이 가장 낮은 타입: grass
# 5. sp_defense가 가장 낮은 타입: bug
# 6. speed가 가장 낮은 타입: ice
#
# flying 타입은 낮은 hp를 speed로 보완하는 특성
#
# ice 타입은 attack과 speed가 가장 낮지만, 엄청난 sp_defense로 sp_attack을 막는데 탁월
#
# electric 타입은 attack, sp_attack 능력치가 3위/speed 는 4위이나, 기타 능력치는 모두 하위권

# %% [markdown]
# ## legendary 가 아닌 포켓몬의 능력치

# %%
pokemon_stat_avg_non_legendary = pd.read_csv('stat_avg_non_legendary.csv')
pokemon_stat_avg_non_legendary
# Out:
#        type1     total       hp   attack   defense  sp_attack  sp_defense  \
# 0     dragon  458.3500  67.5000  98.6500   78.9000    70.4000     74.9000
# 1      steel  454.8889  58.6111  91.8333  120.4444    60.7222     74.1667
# 2       fire  433.8936  65.7872  78.5745   64.5532    84.6170     68.2979
# 3       dark  430.5000  64.8077  85.5385   69.5000    69.1538     67.7692
# 4       rock  429.9250  64.8750  88.4500   95.6250    58.3750     70.2750
# 5      ghost  425.2692  60.0385  70.9231   78.7308    81.0000     77.4615
# 6        ice  419.6667  70.8571  73.8571   69.2381    75.5238     67.9048
# 7   electric  415.5882  57.2941  67.0000   59.5588    81.2059     68.1176
# 8      water  415.5000  69.0185  71.8981   71.9167    71.2870     69.1667
# 9   fighting  414.8214  71.4286  99.1786   66.3929    50.1071     63.4286
# 10     fairy  412.2941  70.8824  58.0588   66.5882    78.5882     87.1765
# 11    ground  408.8333  71.7667  90.3000   81.1667    46.9000     60.7667
# ...

# %%
pokemon_stat_avg_non_legendary_maxmin = pokemon_stat_avg_non_legendary[pokemon_stat_avg_non_legendary['type1'].isin(['dragon', 'bug'])]
pokemon_stat_avg_non_legendary_maxmin
# Out:
#      type1     total       hp   attack  defense  sp_attack  sp_defense  \
# 0   dragon  458.3500  67.5000  98.6500     78.9    70.4000     74.9000
# 17     bug  371.7536  55.5797  67.4348     70.0    54.6232     62.5507
#
#       speed
# 0   68.0000
# 17  61.5652

# %%
pokemon_stat_avg_non_legendary_maxmin['total'].diff()
# Out:
# 0         NaN
# 17   -86.5964
# Name: total, dtype: float64

# %%
barlist02 = plt.bar(data = pokemon_stat_avg_non_legendary, x = 'type1', height = 'total', color = 'grey')
barlist02[0].set_color('tab:blue')
barlist02[17].set_color('tab:red')
plt.xticks(rotation = 45)

plt.show()

# %% [markdown]
# ## legendary가 아닌 포켓몬
# - dragon 타입이 가장 강하고, bug 타입이 가장 약했다.
# - 가장 강한 타입과 가장 약한 타입의 total 차이는 약 87이다.

# %% [markdown]
# ## legendary 가 아닌 포켓몬 능력치 추가 분석

# %%
pokemon_stat_avg_non_legendary_nontotal = pokemon_stat_avg_non_legendary.drop('total', axis = 1)
pokemon_stat_avg_non_legendary_nontotal
# Out:
#        type1       hp   attack   defense  sp_attack  sp_defense    speed
# 0     dragon  67.5000  98.6500   78.9000    70.4000     74.9000  68.0000
# 1      steel  58.6111  91.8333  120.4444    60.7222     74.1667  49.1111
# 2       fire  65.7872  78.5745   64.5532    84.6170     68.2979  72.0638
# 3       dark  64.8077  85.5385   69.5000    69.1538     67.7692  73.7308
# 4       rock  64.8750  88.4500   95.6250    58.3750     70.2750  52.3250
# 5      ghost  60.0385  70.9231   78.7308    81.0000     77.4615  57.1154
# 6        ice  70.8571  73.8571   69.2381    75.5238     67.9048  62.2857
# 7   electric  57.2941  67.0000   59.5588    81.2059     68.1176  82.4118
# 8      water  69.0185  71.8981   71.9167    71.2870     69.1667  62.2130
# 9   fighting  71.4286  99.1786   66.3929    50.1071     63.4286  64.2857
# 10     fairy  70.8824  58.0588   66.5882    78.5882     87.1765  51.0000
# 11    ground  71.7667  90.3000   81.1667    46.9000     60.7667  57.9333
# ...

# %%
pokemon_stat_avg_non_legendary_nontotal = pokemon_stat_avg_non_legendary_nontotal.set_index('type1')
pokemon_stat_avg_non_legendary_nontotal
# Out:
#                hp   attack   defense  sp_attack  sp_defense    speed
# type1
# dragon    67.5000  98.6500   78.9000    70.4000     74.9000  68.0000
# steel     58.6111  91.8333  120.4444    60.7222     74.1667  49.1111
# fire      65.7872  78.5745   64.5532    84.6170     68.2979  72.0638
# dark      64.8077  85.5385   69.5000    69.1538     67.7692  73.7308
# rock      64.8750  88.4500   95.6250    58.3750     70.2750  52.3250
# ghost     60.0385  70.9231   78.7308    81.0000     77.4615  57.1154
# ice       70.8571  73.8571   69.2381    75.5238     67.9048  62.2857
# electric  57.2941  67.0000   59.5588    81.2059     68.1176  82.4118
# water     69.0185  71.8981   71.9167    71.2870     69.1667  62.2130
# fighting  71.4286  99.1786   66.3929    50.1071     63.4286  64.2857
# fairy     70.8824  58.0588   66.5882    78.5882     87.1765  51.0000
# ground    71.7667  90.3000   81.1667    46.9000     60.7667  57.9333
# ...

# %%
pokemon_stat_avg_non_legendary_nontotal_t = pokemon_stat_avg_non_legendary_nontotal.T
pokemon_stat_avg_non_legendary_nontotal_t
# Out:
# type1       dragon     steel     fire     dark    rock    ghost      ice  \
# hp           67.50   58.6111  65.7872  64.8077  64.875  60.0385  70.8571
# attack       98.65   91.8333  78.5745  85.5385  88.450  70.9231  73.8571
# defense      78.90  120.4444  64.5532  69.5000  95.625  78.7308  69.2381
# sp_attack    70.40   60.7222  84.6170  69.1538  58.375  81.0000  75.5238
# sp_defense   74.90   74.1667  68.2979  67.7692  70.275  77.4615  67.9048
# speed        68.00   49.1111  72.0638  73.7308  52.325  57.1154  62.2857
#
# type1       electric    water  fighting    fairy   ground    grass  psychic  \
# hp           57.2941  69.0185   71.4286  70.8824  71.7667  64.5676  65.1944
# attack       67.0000  71.8981   99.1786  58.0588  90.3000  70.9459  50.1389
# defense      59.5588  71.9167   66.3929  66.5882  81.1667  69.3919  57.2778
# sp_attack    81.2059  71.2870   50.1071  78.5882  46.9000  73.5541  86.5000
# ...

# %%
sns.boxplot(data = pokemon_stat_avg_non_legendary_nontotal)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### legendary가 아닌 포켓몬의 능력치 분포
#
# - attack이 타입별로 가장 차이가 많이 난다.
# - hp, defense, sp_defense는 상대적으로 밀집되어있다. 타입별 차이가 적다는 뜻.
# - defense, sp_defense, speed에서 눈에 띄게 높은 타입이 1~2개 존재한다.

# %%
fig = plt.figure(figsize=(18,14))


plt.subplot(2, 3, 1)
g01 = plt.bar(data = pokemon_stat_avg_non_legendary, x = 'type1', height = 'hp', color = 'grey')
g01[15].set_color('tab:blue')
g01[17].set_color('tab:red')
plt.title('hp')
plt.xticks(rotation = 45)

plt.subplot(2, 3, 2)
g02 = plt.bar(data = pokemon_stat_avg_non_legendary, x = 'type1', height = 'attack', color = 'grey')
g02[9].set_color('tab:blue')
g02[16].set_color('tab:red')
plt.title('attack')
plt.xticks(rotation = 45)

plt.subplot(2, 3, 3)
g03 = plt.bar(data = pokemon_stat_avg_non_legendary, x = 'type1', height = 'defense', color = 'grey')
g03[1].set_color('tab:blue')
g03[13].set_color('tab:red')
plt.title('defense')
plt.xticks(rotation = 45)

plt.subplot(2, 3, 4)
g04 = plt.bar(data = pokemon_stat_avg_non_legendary, x = 'type1', height = 'sp_attack', color = 'grey')
g04[13].set_color('tab:blue')
g04[11].set_color('tab:red')
plt.title('sp_attack')
plt.xticks(rotation = 45)

plt.subplot(2, 3, 5)
g05 = plt.bar(data = pokemon_stat_avg_non_legendary, x = 'type1', height = 'sp_defense', color = 'grey')
g05[10].set_color('tab:blue')
g05[16].set_color('tab:red')
plt.title('sp_defense')
plt.xticks(rotation = 45)

plt.subplot(2, 3, 6)
g06 = plt.bar(data = pokemon_stat_avg_non_legendary, x = 'type1', height = 'speed', color = 'grey')
g06[16].set_color('tab:blue')
g06[1].set_color('tab:red')
plt.title('speed')
plt.xticks(rotation = 45)

plt.show()

# %% [markdown]
# ### 능력치별 가장 높은 타입
# 1. hp가 가장 높은 타입: normal
# 2. attack이 가장 높은 타입: fighting
# 3. defense가 가장 높은 타입: steel
# 4. sp_attack이 가장 높은 타입: psychic
# 5. sp_defense가 가장 높은 타입: fairy
# 6. speed가 가장 높은 타입: flying
#
# dragon 타입과 steel 타입은 total이 매우 비슷하나 근소한 차이(4)로 dragon타입이 1위. steel은 defense가 월등히 높으나, 그 외 모든 능력치는 gragon이 더 높음
#
#
# ### 능력치별 가장 낮은 타입
# 1. hp가 가장 낮은 타입: bug
# 2. attack이 가장 낮은 타입: flying
# 3. defense가 가장 낮은 타입: psychic
# 4. sp_attack이 가장 낮은 타입: ground
# 5. sp_defense가 가장 낮은 타입: flying
# 6. speed가 가장 낮은 타입: steel

# %% [markdown]
# # Legendary 와 그렇지 않은 포켓몬 비교
#
# ### Legendary 포켓몬의 각 능력치 평균은 그렇지 않은 포켓몬의 것에 비해 10% 이상 높을 것이다.

# %% [markdown]
# ### legendary 평균

# %%
stat_avg_by_legendary = pd.DataFrame(pokemon_stat_legendary.mean())
stat_avg_by_legendary
# Out:
# /var/folders/j2/qvzy45bn0l71dytmdq4v9r6r0000gn/T/ipykernel_53414/1725087597.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   stat_avg_by_legendary = pd.DataFrame(pokemon_stat_legendary.mean())
#                        0
# base_total    615.257143
# attack        109.357143
# defense        99.400000
# hp             95.428571
# sp_attack     113.757143
# sp_defense    101.885714
# speed          95.428571
# generation      4.557143
# is_legendary    1.000000

# %% [markdown]
# ### legendary가 아닌 평균

# %%
stat_avg_by_legendary = stat_avg_by_legendary.assign(x = pokemon_stat_non_legendary.mean())
stat_avg_by_legendary
# Out:
# /var/folders/j2/qvzy45bn0l71dytmdq4v9r6r0000gn/T/ipykernel_53414/2446606857.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   stat_avg_by_legendary = stat_avg_by_legendary.assign(x = pokemon_stat_non_legendary.mean())
#                        0           x
# base_total    615.257143  410.481532
# attack        109.357143   74.841313
# defense        99.400000   70.481532
# hp             95.428571   66.424077
# sp_attack     113.757143   67.240766
# sp_defense    101.885714   67.945280
# speed          95.428571   63.548564
# generation      4.557143    3.607387
# is_legendary    1.000000    0.000000

# %%
stat_avg_by_legendary['diff'] = stat_avg_by_legendary[0] - stat_avg_by_legendary['x']
stat_avg_by_legendary
# Out:
#                        0           x        diff
# base_total    615.257143  410.481532  204.775611
# attack        109.357143   74.841313   34.515830
# defense        99.400000   70.481532   28.918468
# hp             95.428571   66.424077   29.004495
# sp_attack     113.757143   67.240766   46.516377
# sp_defense    101.885714   67.945280   33.940434
# speed          95.428571   63.548564   31.880008
# generation      4.557143    3.607387    0.949756
# is_legendary    1.000000    0.000000    1.000000

# %%
stat_avg_by_legendary['diff_percent'] = ((stat_avg_by_legendary[0] - stat_avg_by_legendary['x']) / stat_avg_by_legendary['x']) * 100
stat_avg_by_legendary
# Out:
#                        0           x        diff  diff_percent
# base_total    615.257143  410.481532  204.775611     49.886681
# attack        109.357143   74.841313   34.515830     46.118685
# defense        99.400000   70.481532   28.918468     41.029851
# hp             95.428571   66.424077   29.004495     43.665635
# sp_attack     113.757143   67.240766   46.516377     69.178832
# sp_defense    101.885714   67.945280   33.940434     49.952600
# speed          95.428571   63.548564   31.880008     50.166370
# generation      4.557143    3.607387    0.949756     26.328078
# is_legendary    1.000000    0.000000    1.000000           inf

# %%
stat_avg_by_legendary = stat_avg_by_legendary.reset_index()
stat_avg_by_legendary
# Out:
#           index           0           x        diff  diff_percent
# 0    base_total  615.257143  410.481532  204.775611     49.886681
# 1        attack  109.357143   74.841313   34.515830     46.118685
# 2       defense   99.400000   70.481532   28.918468     41.029851
# 3            hp   95.428571   66.424077   29.004495     43.665635
# 4     sp_attack  113.757143   67.240766   46.516377     69.178832
# 5    sp_defense  101.885714   67.945280   33.940434     49.952600
# 6         speed   95.428571   63.548564   31.880008     50.166370
# 7    generation    4.557143    3.607387    0.949756     26.328078
# 8  is_legendary    1.000000    0.000000    1.000000           inf

# %%
stat_avg_by_legendary_no_total = stat_avg_by_legendary.drop([0,7,8])
stat_avg_by_legendary_no_total
# Out:
#         index           0          x       diff  diff_percent
# 1      attack  109.357143  74.841313  34.515830     46.118685
# 2     defense   99.400000  70.481532  28.918468     41.029851
# 3          hp   95.428571  66.424077  29.004495     43.665635
# 4   sp_attack  113.757143  67.240766  46.516377     69.178832
# 5  sp_defense  101.885714  67.945280  33.940434     49.952600
# 6       speed   95.428571  63.548564  31.880008     50.166370

# %%
stat_avg_by_legendary_no_total.mean()
# Out:
# /var/folders/j2/qvzy45bn0l71dytmdq4v9r6r0000gn/T/ipykernel_53414/871829227.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   stat_avg_by_legendary_no_total.mean()
# 0               102.542857
# x                68.413589
# diff             34.129268
# diff_percent     50.018662
# dtype: float64

# %% [markdown]
# #### legendary와 no legendary 능력치 평균 비교 결과
#  - no legendary 포켓몬의 능력치에 비해 legendary인 포켓몬의 능력치가 평균 50% 이상 높다.(평균 약34정도 차이)

# %%
f, axs = plt.subplots(1, 2, figsize = (10, 5), sharey = True)

g01 = sns.barplot(data = stat_avg_by_legendary_no_total, x = 'index', y = 0, ax = axs[0])
g01.tick_params(axis='x', rotation=45)
g01.set(xlabel = 'legendary', ylabel = '')

g02 = sns.barplot(data = stat_avg_by_legendary_no_total, x = 'index', y = 'x', ax = axs[1])
g02.tick_params(axis='x', rotation=45)
g02.set(xlabel = 'no legendary', ylabel = '')
plt.show()

# %% [markdown]
# # 타입 개수별 능력치 비교
#
#
# 타입이 1개일 때와 2개일 때의 능력치 평균 비교

# %%
pokemon_stat
# Out:
#                 attack  base_total  defense   hp        name  sp_attack  \
# pokedex_number
# 1                   49         318       49   45   Bulbasaur         65
# 2                   62         405       63   60     Ivysaur         80
# 3                  100         625      123   80    Venusaur        122
# 4                   52         309       43   39  Charmander         60
# 5                   64         405       58   58  Charmeleon         80
# ...                ...         ...      ...  ...         ...        ...
# 797                101         570      103   97  Celesteela        107
# 798                181         570      131   59     Kartana         59
# 799                101         570       53  223    Guzzlord         97
# 800                107         600      101   97    Necrozma        127
# 801                 95         600      115   80    Magearna        130
#
#                 sp_defense  speed    type1   type2  generation  is_legendary
# ...

# %%
pokemon_stat_type1 = pokemon_stat[pokemon_stat['type2'] == 'None']
pokemon_stat_type1
# Out:
#                 attack  base_total  defense  hp        name  sp_attack  \
# pokedex_number
# 4                   52         309       43  39  Charmander         60
# 5                   64         405       58  58  Charmeleon         80
# 7                   48         314       65  44    Squirtle         50
# 8                   63         405       80  59   Wartortle         65
# 9                  103         630      120  79   Blastoise        135
# ...                ...         ...      ...  ..         ...        ...
# 782                 55         300       65  45    Jangmo-o         45
# 789                 29         200       31  43      Cosmog         29
# 790                 29         400      131  43     Cosmoem         29
# 796                 89         570       71  83   Xurkitree        173
# 800                107         600      101  97    Necrozma        127
#
#                 sp_defense  speed     type1 type2  generation  is_legendary
# pokedex_number
# ...

# %%
pokemon_stat_type2 = pokemon_stat[pokemon_stat['type2'] != 'None']
pokemon_stat_type2
# Out:
#                 attack  base_total  defense   hp        name  sp_attack  \
# pokedex_number
# 1                   49         318       49   45   Bulbasaur         65
# 2                   62         405       63   60     Ivysaur         80
# 3                  100         625      123   80    Venusaur        122
# 6                  104         634       78   78   Charizard        159
# 12                  45         395       50   60  Butterfree         90
# ...                ...         ...      ...  ...         ...        ...
# 795                137         570       37   71   Pheromosa        137
# 797                101         570      103   97  Celesteela        107
# 798                181         570      131   59     Kartana         59
# 799                101         570       53  223    Guzzlord         97
# 801                 95         600      115   80    Magearna        130
#
#                 sp_defense  speed  type1     type2  generation  is_legendary
# ...

# %%
pokemon_stat_type1.mean()
# Out:
# /var/folders/j2/qvzy45bn0l71dytmdq4v9r6r0000gn/T/ipykernel_53414/3952248930.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pokemon_stat_type1.mean()
# attack           74.231771
# base_total      409.354167
# defense          67.955729
# hp               67.611979
# sp_attack        67.815104
# sp_defense       68.135417
# speed            63.604167
# generation        3.606771
# is_legendary      0.065104
# dtype: float64

# %%
pokemon_stat_type2.mean()
# Out:
# /var/folders/j2/qvzy45bn0l71dytmdq4v9r6r0000gn/T/ipykernel_53414/2665694354.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pokemon_stat_type2.mean()
# attack           81.196643
# base_total      445.894484
# defense          77.661871
# hp               70.199041
# sp_attack        74.520384
# sp_defense       73.467626
# speed            68.848921
# generation        3.767386
# is_legendary      0.107914
# dtype: float64

# %%
stat_by_type_number = pd.DataFrame(pokemon_stat_type1.mean())
stat_by_type_number
# Out:
# /var/folders/j2/qvzy45bn0l71dytmdq4v9r6r0000gn/T/ipykernel_53414/4048096168.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   stat_by_type_number = pd.DataFrame(pokemon_stat_type1.mean())
#                        0
# attack         74.231771
# base_total    409.354167
# defense        67.955729
# hp             67.611979
# sp_attack      67.815104
# sp_defense     68.135417
# speed          63.604167
# generation      3.606771
# is_legendary    0.065104

# %%
stat_by_type_number = stat_by_type_number.rename(columns = {0 : 'type1'})

# %%
stat_by_type_number['type2'] = pokemon_stat_type2.mean()
stat_by_type_number
# Out:
# /var/folders/j2/qvzy45bn0l71dytmdq4v9r6r0000gn/T/ipykernel_53414/2651828828.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   stat_by_type_number['type2'] = pokemon_stat_type2.mean()
#                    type1       type2
# attack         74.231771   81.196643
# base_total    409.354167  445.894484
# defense        67.955729   77.661871
# hp             67.611979   70.199041
# sp_attack      67.815104   74.520384
# sp_defense     68.135417   73.467626
# speed          63.604167   68.848921
# generation      3.606771    3.767386
# is_legendary    0.065104    0.107914

# %%
stat_by_type_number = stat_by_type_number.drop('is_legendary')

# %%
stat_by_type_number = stat_by_type_number.drop('generation')

# %%
stat_by_type_number_nontotal = stat_by_type_number.drop('base_total')

# %%
df_stat_by_type_number_nontotal = stat_by_type_number_nontotal.reset_index()
df_stat_by_type_number_nontotal
# Out:
#         index      type1      type2
# 0      attack  74.231771  81.196643
# 1     defense  67.955729  77.661871
# 2          hp  67.611979  70.199041
# 3   sp_attack  67.815104  74.520384
# 4  sp_defense  68.135417  73.467626
# 5       speed  63.604167  68.848921

# %%
f, axs = plt.subplots(1, 2, figsize = (10, 5), sharey = True)

g01 = sns.barplot(data = df_stat_by_type_number_nontotal, x = 'index', y = 'type1', ax = axs[0])
g01.tick_params(axis='x', rotation=45)
g01.set(xlabel = 'has 1 type', ylabel = '')

g02 = sns.barplot(data = df_stat_by_type_number_nontotal, x = 'index', y = 'type2', ax = axs[1])
g02.tick_params(axis='x', rotation=45)
g02.set(xlabel = 'has 2 types', ylabel = '')
plt.show()

# %%
# 타입 개수별 차이
stat_by_type_number['type2'] - stat_by_type_number['type1']
# Out:
# attack         6.964872
# base_total    36.540318
# defense        9.706141
# hp             2.587062
# sp_attack      6.705280
# sp_defense     5.332209
# speed          5.244754
# dtype: float64

# %%
#타입이 1개인 포켓몬에 비한 차이 퍼센트 변환
((stat_by_type_number['type2'] - stat_by_type_number['type1']) / stat_by_type_number['type1']) *100
# Out:
# attack         9.382602
# base_total     8.926333
# defense       14.283036
# hp             3.826336
# sp_attack      9.887590
# sp_defense     7.825900
# speed          8.245929
# dtype: float64

# %% [markdown]
# - type이 2개인 포켓몬들이 1개인 포켓몬들보다 능력치가 더 높다.</br>
# 전체적으로 약 8~10%의 차이, defense는 약 14%로 가장 많이 차이났으며, hp는 약 4%로 가장 적게 차이났다.

# %% [markdown]
# # * 가장 강한 포켓몬 1가지는?
# ### 한정된 자원으로 1가지 포켓몬만 키울 수 있다면, 어떤 것을 키우는게 가장 많은 포켓몬을 상대로 이길 수 있을까?

# %% [markdown]
# 포켓몬을 기반으로한 게임은 꽤 많아서, 계산식과 기본 능력치 기준이 다 다르다. 너무 복잡해지는 것을 막기 위해 몇가지를 통일하였다.
#
# 1. 능력치
#  - 레벨이 올라가면 더 좋은 능력치를 갖게 되나, 여기서는 **레벨을 고려하지 않은 기본 능력치를 기준**으로 계산한다.
#
#
# 2. 진화형태
#  - 이상해씨->이상해풀->이상해꽃 등과 같은 진화 형태는 각자의 개체로 본다.
#
#
# 3. 1세대를 기준으로
#
# - 데미지 = (위력 × 공격 × (레벨 × [[급소]] × 2 ÷ 5 + 2 ) ÷ 방어 ÷ 50 + 2 ) × [[자속 보정]] × 타입상성1 × 타입상성2 × 랜덤수/255
#
# - 위력 = [[도우미]] × 기술위력 × 도구보정 × [[충전]] × [[흙놀이]] × [[물놀이]] × 특성보정 × 상대특성보정
#   - 도우미, 도구보정, 충전, 흙놀이, 물놀이, 특성보정, 상태특성보정은 없음. 따라서 위력 = 기술위력인데, 기술의 종류는 745개. 포켓몬의 종류와 기술의 종류의 경우의 수를 따져보면 너무 복잡해져서 해당 변수 삭제.
#
# - 공격 = 스탯 × [[랭크 (상태변화)|랭크]]보정 × [[특성]]보정 × [[도구]]보정
#   - 랭크(기술, 도구에 따른 버프 효과), 특성, 도구 없음. 따라서 공격 = 스탯
#   - 특수 공격은 공격 3번 사용 시 1번 사용할 수 있도록 제한. 특수공격이니까.
#
# - 레벨
#   - 1로 통일
#
# - 급소
#   - 아래와 같이 계산되나, 1세대 제외 모두 6.25%가 기본으로 6.25%로 통일
#   - 급소율의 계산
#     > 6세대
# 기본 = 1/16 (6.25%)
# 1랭크 = 1/8 (12.5%)
# 2랭크 = 1/2 (50%)
# 3랭크 = 1/1 (100%)
# 2~5세대
# 기본 = 1/16 (6.25%)
# 1랭크 = 1/8 (12.5%)
# 2랭크 = 1/4 (25%)
# 3랭크 = 1/3 (33.3%)
# 4랭크 = 1/2 (50%)
# 1세대
# 일반 기술 = 스피드/512
# 급소 보정 기술 = 스피드/64
#
# - 특수방어 = 스탯 × [[랭크]]보정 × Mod × 자폭보정
#   - 랭크(기술, 도구에 따른 버프 효과), Mod(특성, 상태, 기술, 날씨 같은 것), 자폭보정 없음. 따라서 방어 및 특수방어 = 스탯
#   - 특수 방어는 특수 공격 시 발동되는 방어력.
#
# - 자속보정
#   - 사용하는 기술의 타입과 사용하는 포켓몬의 타입이 일치하면 1.5를 대입. 사용하는 기술의 타입과 사용하는 포켓몬의 타입이 일치하면서 적응력 특성의 포켓몬이라면 2를 대입.
#   - 기술은 포켓몬에 따라 랜덤으로 나오고, 배우기 등을 고려하면 복잡하기 때문에 기술 타입과 포켓몬 타입이 일치하고 적응력 등의 특성은 고려하지 않는 것을 전제로 **1.5로 통일.**
#
#
# - 타입상성1, 타입상성2
#   - https://pokemon.fandom.com/ko/wiki/%ED%83%80%EC%9E%85_%EC%83%81%EC%84%B1%ED%91%9C
#   - 상성은 공격하는 기술 : 방어하는 포켓몬의 타입 기준이다.
#   - 타입이 1개인 포켓몬의 경우는 타입 상성표에 있는 그대로 계산하면 된다.
#   - 타입이 2개인 포켓몬은 각 타입의 해당하는 배율을 서로 곱한 결과를 사용한다.
#   - 여기서는 **타입이 1개인 포켓몬은 타입상성표 그대로 계산**하고, **타입이 2개인 포켓몬들은 상대방에게 효과가 더 큰 타입으로 골라서 사용**하는 것으로 한다.
#   > 예를 들어 불꽃/비행타입인 리자몽에게 바위타입의 기술을 사용하면 불꽃타입과 비행타입 각각 2배의 데미지를 받기 때문에 총 4배의 데미지를 받게 된다.
# 반대로 리자몽에게 땅타입의 기술을 사용하면 불꽃타입은 2배, 비행타입은 0배의 데미지를 받기 떄문에 0배의 데미지, 즉 아무런 데미지를 받지 않는다.
# 따라서 불꽃/비행타입인 리자몽과 땅/바위 타입 딱구리가 싸운다면 딱구리는 땅 타입 기술 사용 시 0배, 바위 타입 기술 사용 시 4배의 데미지를 줄 수 있기 때문에 바위 타입 기술로 공격할 것이다.
#
# - 랜덤수
#   - 말 그대로 랜덤으로 나오는 숫자이기 때문에 제외.
#   - 출처: https://pokemon.fandom.com/ko/wiki/%EB%8D%B0%EB%AF%B8%EC%A7%80
#
#
# - 최종 사용 공식 (앞에서부터 차례대로 계산)
#   - 내가 상대에게 주는 데미지 = 내 공격 스탯(또는 특수공격) × (1 × 0.0625 × 2 ÷ 5 + 2 ) ÷ 상대방 방어 스탯(또는 특수방어) ÷ 50 + 2 ) × 1.5 × 타입상성1 × 타입상성2
# 						(내 공격 스탯(또는 특수공격) * 2.025 / 상대방 방어 스탯(또는 특수방어) / 50 + 2 ) * 1.5 * 타입 상성 1 * 타입 상성 2
#   - 공통된 숫자들을 모두 빼면
#   > **내 공격 스탯(또는 특수공격) / 상대방 방어 스탯(또는 특수방어) * 타입 상성 1 * 타입 상성 2**
#
# - 선공 포켓몬: speed가 더 높은 기준
#
# - 이긴다의 기준: 상대 포켓몬의 hp가 0이 되는 순간
#
# - 함수에 필요한 변수: 공격 스탯, 방어 스탯, 특공 스탯, 특방 스탯, 타입 1, 타입 2, 속도, hp -> 포켓몬 2마리 이름 입력 시 자동으로 뽑히도록

# %%
pokemon.head(10)
# Out:
#                 against_bug  against_dark  against_dragon  against_electric  \
# pokedex_number
# 1                      1.00           1.0             1.0               0.5
# 2                      1.00           1.0             1.0               0.5
# 3                      1.00           1.0             1.0               0.5
# 4                      0.50           1.0             1.0               1.0
# 5                      0.50           1.0             1.0               1.0
# 6                      0.25           1.0             1.0               2.0
# 7                      1.00           1.0             1.0               2.0
# 8                      1.00           1.0             1.0               2.0
# 9                      1.00           1.0             1.0               2.0
# 10                     1.00           1.0             1.0               1.0
#
#                 against_fairy  against_fight  against_fire  against_flying  \
# pokedex_number
# ...

# %%
pokemon.columns
# Out:
# Index(['against_bug', 'against_dark', 'against_dragon', 'against_electric',
#        'against_fairy', 'against_fight', 'against_fire', 'against_flying',
#        'against_ghost', 'against_grass', 'against_ground', 'against_ice',
#        'against_normal', 'against_poison', 'against_psychic', 'against_rock',
#        'against_steel', 'against_water', 'attack', 'base_total', 'defense',
#        'hp', 'name', 'sp_attack', 'sp_defense', 'speed', 'type1', 'type2',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
pokemon.iat[pokemon[pokemon['name'] == 'Bulbasaur'].index[0] -1 , 26]
# Out:
# 'grass'

# %%
pokemon.iat[pokemon[pokemon['name'] == 'Ivysaur'].index[0] -1 , 18]
# Out:
# 62

# %%
pokemon['type1'].value_counts()
# Out:
# water       114
# normal      105
# grass        78
# bug          72
# psychic      53
# fire         52
# rock         45
# electric     39
# poison       32
# ground       32
# dark         29
# fighting     28
# ghost        27
# dragon       27
# steel        24
# ice          23
# fairy        18
# flying        3
# Name: type1, dtype: int64

# %%
pokemon_type = {'bug': 0, 
                'dark': 1, 
                'dragon': 2, 
                'electric': 3, 
                'fairy': 4, 
                'fighting': 5, 
                'fire': 6, 
                'flying': 7, 
                'ghost': 8, 
                'grass': 9, 
                'ground': 10, 
                'ice': 11, 
                'normal': 12, 
                'poison': 13, 
                'psychic': 14, 
                'rock': 15, 
                'steel': 16, 
                'water': 17}

# %%
def battle_test (pokemon1_name, pokemon2_name):
#a_test
    a_test_attack = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 18]
    a_test_defense = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 20]
    a_test_hp = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 21]
    a_test_sp_attack = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 23]
    a_test_sp_defense = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 24]
    a_test_speed = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 25]
    a_test_type1 = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 26]
    a_test_type2 = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 27]
    
    #b_test
    b_test_attack = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 18]
    b_test_defense = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 20]
    b_test_hp = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 21]
    b_test_sp_attack = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 23]
    b_test_sp_defense = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 24]
    b_test_speed = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 25]
    b_test_type1 = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 26]
    b_test_type2 = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 27]
    
    
    
    #포켓몬 1
    a_attribute_1 = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , pokemon_type[b_test_type1]]
    if b_test_type2 == 'None':
        a_attribute_2 = 1
    else:
        a_attribute_2 = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , pokemon_type[b_test_type2]]
        
    #포켓몬 2
    b_attribute_1 = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , pokemon_type[a_test_type1]]
    if a_test_type2 == 'None':
        b_attribute_2 = 1
    else:
        b_attribute_2 = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , pokemon_type[a_test_type2]]
    
    
    
    if a_test_speed < b_test_speed :
        a_attack_num = 0
        b_attack_num = 0
        print(pokemon2_name, '선공!')
        
        #한 포켓몬의 체력이 0 이하가 될때까지 배틀 진행
        while a_test_hp >= 0 or b_test_hp >= 0:
                
            #순차적으로 배틀 진행
            a_test_hp = round(a_test_hp - (b_test_attack / a_test_defense * a_attribute_1 * a_attribute_2))
            b_attack_num += 1
            print(pokemon2_name, '공격')
            print(pokemon1_name,' hp :', a_test_hp, '/', 'attack count : ', a_attack_num)
            print(pokemon2_name,' hp :', b_test_hp, '/', 'attack count : ', b_attack_num)

            if a_test_hp <= 0 or b_test_hp <= 0:
                if a_test_hp <= 0:
                    return print('GAME OVER. B win!')
                    break
                elif b_test_hp <= 0:
                    return print('GAME OVER. A win!')
                    break
                else:
                    continue
            
            #attack 3회 후 sp_attack. 반복
            if b_attack_num != 0 and b_attack_num %3 == 0:
                a_test_hp = round(a_test_hp - (b_test_sp_attack / a_test_sp_defense * a_attribute_1 * a_attribute_2))
                print(pokemon2_name, '스페셜 어택!')
                print(pokemon1_name,' hp :', a_test_hp, '/', 'attack count : ', a_attack_num)
                print(pokemon2_name,' hp :', b_test_hp, '/', 'attack count : ', b_attack_num)
                
                if a_test_hp <= 0 or b_test_hp <= 0:
                    if a_test_hp <= 0:
                        return print('GAME OVER. B win!')
                        break
                    elif b_test_hp <= 0:
                        return print('GAME OVER. A win!')
                        break
                    else:
                        continue

            b_test_hp = round(b_test_hp - (a_test_attack / b_test_defense * b_attribute_1 * b_attribute_2))
            a_attack_num += 1
            print(pokemon1_name, '공격')
            print(pokemon1_name,' hp :', a_test_hp, '/', 'attack count : ', a_attack_num)
            print(pokemon2_name,' hp :', b_test_hp, '/', 'attack count : ', b_attack_num)
            
            if a_test_hp <= 0 or b_test_hp <= 0:
                if a_test_hp <= 0:
                    return print('GAME OVER. B win!')
                    break
                elif b_test_hp <= 0:
                    return print('GAME OVER. A win!')
                    break
                else:
                    continue

            #attack 3회 후 sp_attack. 반복
            if a_attack_num != 0 and a_attack_num %3 == 0:
                b_test_hp = round(b_test_hp - (a_test_sp_attack / b_test_sp_defense * b_attribute_1 * b_attribute_2))
                print(pokemon1_name, '스페셜 어택!')
                print(pokemon1_name,' hp :', a_test_hp, '/', 'attack count : ', a_attack_num)
                print(pokemon2_name,' hp :', b_test_hp, '/', 'attack count : ', b_attack_num)
                
                if a_test_hp <= 0 or b_test_hp <= 0:
                    if a_test_hp <= 0:
                        return print('GAME OVER. B win!')
                        break
                    elif b_test_hp <= 0:
                        return print('GAME OVER. A win!')
                        break
                    else:
                        continue

# %%
battle_test('Venusaur', 'Charizard')
# Out:
# Charizard 선공!
# Charizard 공격
# Venusaur  hp : 77 / attack count :  0
# Charizard  hp : 78 / attack count :  1
# Venusaur 공격
# Venusaur  hp : 77 / attack count :  1
# Charizard  hp : 78 / attack count :  1
# Charizard 공격
# Venusaur  hp : 74 / attack count :  1
# Charizard  hp : 78 / attack count :  2
# Venusaur 공격
# Venusaur  hp : 74 / attack count :  2
# Charizard  hp : 78 / attack count :  2
# Charizard 공격
# Venusaur  hp : 71 / attack count :  2
# Charizard  hp : 78 / attack count :  3
# Charizard 스페셜 어택!
# Venusaur  hp : 66 / attack count :  2
# Charizard  hp : 78 / attack count :  3
# Venusaur 공격
# Venusaur  hp : 66 / attack count :  3
# Charizard  hp : 78 / attack count :  3
# Venusaur 스페셜 어택!
# Venusaur  hp : 66 / attack count :  3
# Charizard  hp : 78 / attack count :  3
# Charizard 공격
# Venusaur  hp : 63 / attack count :  3
# Charizard  hp : 78 / attack count :  4
# Venusaur 공격
# Venusaur  hp : 63 / attack count :  4
# Charizard  hp : 78 / attack count :  4
# Charizard 공격
# ...

# %%
#Venusaur가 입는 데미지

print(pokemon.iat[pokemon[pokemon['name'] == 'Venusaur'].index[0] -1 , pokemon_type['fire']])
print(pokemon.iat[pokemon[pokemon['name'] == 'Venusaur'].index[0] -1 , pokemon_type['flying']])
# Out:
# 2.0
# 2.0

# %%
import random

# %%
#실시간 중계 버전

def battle_no_skip (pokemon1_name, pokemon2_name):
    print(pokemon1_name, 'VS', pokemon2_name)
    print('          fight!          ')
    #a = 포켓몬 1
    a_attack = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 18]
    a_defense = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 20]
    a_hp = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 21]
    a_sp_attack = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 23]
    a_sp_defense = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 24]
    a_speed = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 25]
    a_type1 = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 26]
    a_type2 = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 27]
    
    #b = 포켓몬 2
    b_attack = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 18]
    b_defense = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 20]
    b_hp = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 21]
    b_sp_attack = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 23]
    b_sp_defense = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 24]
    b_speed = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 25]
    b_type1 = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 26]
    b_type2 = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 27]
    
    
    
    # 스킬 타입 정하기. 최초 1회만 하면 됨. attribute
    #((a타입상성1 * b타입상성1) * (a타입상성1 *b 타입상성2))
    #((a타입상성2 * b타입상성1) * (a타입상성2 *b 타입상성2))
    #첫번째 타입은 필수, 두번째 타입이 없을 때는 1(첫번째 타입의 값에 영향을 주면 안됨)
    
    #포켓몬 1
    a_attribute_1 = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , pokemon_type[b_type1]]
    if b_type2 == 'None':
        a_attribute_2 = 1
    else:
        a_attribute_2 = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , pokemon_type[b_type2]]
        
    #포켓몬 2
    b_attribute_1 = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , pokemon_type[a_type1]]
    if a_type2 == 'None':
        b_attribute_2 = 1
    else:
        b_attribute_2 = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , pokemon_type[a_type2]]

    
    # attribute 변수가 0일 때 무승부 기록
    # a, b 둘 다 변수 둘 중 하나가 0일 때 비김
    if (a_attribute_1 == 0 or a_attribute_2 == 0) and (b_attribute_1 == 0 or b_attribute_2 == 0):
        battle_result.loc[len(battle_result)] = ['none', 'none', pokemon1_name, pokemon2_name]
        return
    
    # a 포켓몬(첫번째 입력 포켓몬)의 attribute가 둘 중 하나라도 0일때, b 가 자동 이김
    if (a_attribute_1 == 0 or a_attribute_2 == 0) and (b_attribute_1 != 0 and b_attribute_2 != 0):
        battle_result.loc[len(battle_result)] = [pokemon2_name, pokemon1_name, 'none', 'none']
        return

    # b 포켓몬(첫번째 입력 포켓몬)의 attribute가 둘 중 하나라도 0일때, a 가 자동 이김
    if (a_attribute_1 != 0 and a_attribute_2 != 0) and (b_attribute_1 == 0 or b_attribute_2 == 0):
        battle_result.loc[len(battle_result)] = [pokemon1_name, pokemon2_name, 'none', 'none']
        return
    
        
    #포켓몬 1 선공일 때
    if a_speed > b_speed :
        a_attack_num = 0
        b_attack_num = 0
        print(pokemon1_name, '선공!')

        #한 포켓몬의 체력이 0 이하가 될때까지 배틀 진행
        while a_hp >= 0 or b_hp >= 0:
            
            #순차적으로 배틀 진행
            b_hp = round(b_hp - (a_attack / b_defense * b_attribute_1 * b_attribute_2), 3)
            a_attack_num += 1
            print(pokemon1_name, '공격')
            print(pokemon1_name,' hp :', a_hp, '/', 'attack count : ', a_attack_num)
            print(pokemon2_name,' hp :', b_hp, '/', 'attack count : ', b_attack_num)
            
            if a_hp <= 0 or b_hp <= 0:
                    if a_hp <= 0:
                        return print(pokemon2_name, ' win!')
                        break
                    elif b_hp <= 0:
                        return print(pokemon1_name, ' win!')
                        break
                    else:
                        continue
            
            #attack 3회 후 sp_attack. 반복
            if a_attack_num != 0 and a_attack_num %3 == 0:
                b_hp = round(b_hp - (a_sp_attack / b_sp_defense * b_attribute_1 * b_attribute_2), 3)
                print(pokemon1_name, '스페셜 어택!')
                print(pokemon1_name,' hp :', a_hp, '/', 'attack count : ', a_attack_num)
                print(pokemon2_name,' hp :', b_hp, '/', 'attack count : ', b_attack_num)
                
                if a_hp <= 0 or b_hp <= 0:
                    if a_hp <= 0:
                        return print(pokemon2_name, ' win!')
                        break
                    elif b_hp <= 0:
                        return print(pokemon1_name, ' win!')
                        break
                    else:
                        continue

            a_hp = round(a_hp - (b_attack / a_defense * a_attribute_1 * a_attribute_2), 3)
            b_attack_num += 1
            print(pokemon2_name, '공격')
            print(pokemon1_name,' hp :', a_hp, '/', 'attack count : ', a_attack_num)
            print(pokemon2_name,' hp :', b_hp, '/', 'attack count : ', b_attack_num)

            if a_hp <= 0 or b_hp <= 0:
                if a_hp <= 0:
                    return print(pokemon2_name, ' win!')
                    break
                elif b_hp <= 0:
                    return print(pokemon1_name, ' win!')
                    break
                else:
                    continue
            
            #attack 3회 후 sp_attack. 반복
            if b_attack_num != 0 and b_attack_num %3 == 0:
                a_hp = round(a_hp - (b_sp_attack / a_sp_defense * a_attribute_1 * a_attribute_2), 3)
                print(pokemon2_name, '스페셜 어택!')
                print(pokemon1_name,' hp :', a_hp, '/', 'attack count : ', a_attack_num)
                print(pokemon2_name,' hp :', b_hp, '/', 'attack count : ', b_attack_num)
                
                if a_hp <= 0 or b_hp <= 0:
                    if a_hp <= 0:
                        return print(pokemon2_name, ' win!')
                        break
                    elif b_hp <= 0:
                        return print(pokemon1_name, ' win!')
                        break
                    else:
                        continue
                
            
        
    #포켓몬 2 선공일 때
    elif a_speed < b_speed :
        a_attack_num = 0
        b_attack_num = 0
        print(pokemon2_name, '선공!')
        
        #한 포켓몬의 체력이 0 이하가 될때까지 배틀 진행
        while a_hp >= 0 or b_hp >= 0:
                
            #순차적으로 배틀 진행
            a_hp = round(a_hp - (b_attack / a_defense * a_attribute_1 * a_attribute_2), 3)
            b_attack_num += 1
            print(pokemon2_name, '공격')
            print(pokemon1_name,' hp :', a_hp, '/', 'attack count : ', a_attack_num)
            print(pokemon2_name,' hp :', b_hp, '/', 'attack count : ', b_attack_num)

            if a_hp <= 0 or b_hp <= 0:
                if a_hp <= 0:
                    return print(pokemon2_name, ' win!')
                    break
                elif b_hp <= 0:
                    return print(pokemon1_name, ' win!')
                    break
                else:
                    continue
            
            #attack 3회 후 sp_attack. 반복
            if b_attack_num != 0 and b_attack_num %3 == 0:
                a_hp = round(a_hp - (b_sp_attack / a_sp_defense * a_attribute_1 * a_attribute_2), 3)
                print(pokemon2_name, '스페셜 어택!')
                print(pokemon1_name,' hp :', a_hp, '/', 'attack count : ', a_attack_num)
                print(pokemon2_name,' hp :', b_hp, '/', 'attack count : ', b_attack_num)
                
                if a_hp <= 0 or b_hp <= 0:
                    if a_hp <= 0:
                        return print(pokemon2_name, ' win!')
                        break
                    elif b_hp <= 0:
                        return print(pokemon1_name, ' win!')
                        break
                    else:
                        continue

            b_hp = round(b_hp - (a_attack / b_defense * b_attribute_1 * b_attribute_2), 3)
            a_attack_num += 1
            print(pokemon1_name, '공격')
            print(pokemon1_name,' hp :', a_hp, '/', 'attack count : ', a_attack_num)
            print(pokemon2_name,' hp :', b_hp, '/', 'attack count : ', b_attack_num)
            
            if a_hp <= 0 or b_hp <= 0:
                if a_hp <= 0:
                    return print(pokemon2_name, ' win!')
                    break
                elif b_hp <= 0:
                    return print(pokemon1_name, ' win!')
                    break
                else:
                    continue

            #attack 3회 후 sp_attack. 반복
            if a_attack_num != 0 and a_attack_num %3 == 0:
                b_hp = round(b_hp - (a_sp_attack / b_sp_defense * b_attribute_1 * b_attribute_2), 3)
                print(pokemon1_name, '스페셜 어택!')
                print(pokemon1_name,' hp :', a_hp, '/', 'attack count : ', a_attack_num)
                print(pokemon2_name,' hp :', b_hp, '/', 'attack count : ', b_attack_num)
                
                if a_hp <= 0 or b_hp <= 0:
                    if a_hp <= 0:
                        return print(pokemon2_name, ' win!')
                        break
                    elif b_hp <= 0:
                        return print(pokemon1_name, ' win!')
                        break
                    else:
                        continue

                
        
            
    #포켓몬 1, 2 speed 같을 때 선공 정하기
    else:
        speed_random = random.sample(range(3), 2)
        a_speed = speed_random[0]
        b_speed = speed_random[1]

        #포켓몬 1이 더 빠를 때
        if a_speed > b_speed :
            a_attack_num = 0
            b_attack_num = 0
            print(pokemon1_name, '선공!')

            #한 포켓몬의 체력이 0 이하가 될때까지 배틀 진행
            while a_hp >= 0 or b_hp >= 0:

                #순차적으로 배틀 진행
                b_hp = round(b_hp - (a_attack / b_defense * b_attribute_1 * b_attribute_2), 3)
                a_attack_num += 1
                print(pokemon1_name, '공격')
                print(pokemon1_name,' hp :', a_hp, '/', 'attack count : ', a_attack_num)
                print(pokemon2_name,' hp :', b_hp, '/', 'attack count : ', b_attack_num)

                if a_hp <= 0 or b_hp <= 0:
                        if a_hp <= 0:
                            return print(pokemon2_name, ' win!')
                            break
                        elif b_hp <= 0:
                            return print(pokemon1_name, ' win!')
                            break
                        else:
                            continue

                #attack 3회 후 sp_attack. 반복
                if a_attack_num != 0 and a_attack_num %3 == 0:
                    b_hp = round(b_hp - (a_sp_attack / b_sp_defense * b_attribute_1 * b_attribute_2), 3)
                    print(pokemon1_name, '스페셜 어택!')
                    print(pokemon1_name,' hp :', a_hp, '/', 'attack count : ', a_attack_num)
                    print(pokemon2_name,' hp :', b_hp, '/', 'attack count : ', b_attack_num)

                    if a_hp <= 0 or b_hp <= 0:
                        if a_hp <= 0:
                            return print(pokemon2_name, ' win!')
                            break
                        elif b_hp <= 0:
                            return print(pokemon1_name, ' win!')
                            break
                        else:
                            continue

                a_hp = round(a_hp - (b_attack / a_defense * a_attribute_1 * a_attribute_2), 3)
                b_attack_num += 1
                print(pokemon2_name, '공격')
                print(pokemon1_name,' hp :', a_hp, '/', 'attack count : ', a_attack_num)
                print(pokemon2_name,' hp :', b_hp, '/', 'attack count : ', b_attack_num)

                if a_hp <= 0 or b_hp <= 0:
                    if a_hp <= 0:
                        return print(pokemon2_name, ' win!')
                        break
                    elif b_hp <= 0:
                        return print(pokemon1_name, ' win!')
                        break
                    else:
                        continue

                #attack 3회 후 sp_attack. 반복
                if b_attack_num != 0 and b_attack_num %3 == 0:
                    a_hp = round(a_hp - (b_sp_attack / a_sp_defense * a_attribute_1 * a_attribute_2), 3)
                    print(pokemon2_name, '스페셜 어택!')
                    print(pokemon1_name,' hp :', a_hp, '/', 'attack count : ', a_attack_num)
                    print(pokemon2_name,' hp :', b_hp, '/', 'attack count : ', b_attack_num)

                    if a_hp <= 0 or b_hp <= 0:
                        if a_hp <= 0:
                            return print(pokemon2_name, ' win!')
                            break
                        elif b_hp <= 0:
                            return print(pokemon1_name, ' win!')
                            break
                        else:
                            continue
                
                
        #포켓몬 2가 더 빠를 때
        elif a_speed < b_speed :
            a_attack_num = 0
            b_attack_num = 0
            print(pokemon2_name, '선공!')

            #한 포켓몬의 체력이 0 이하가 될때까지 배틀 진행
            while a_hp >= 0 or b_hp >= 0:

                #순차적으로 배틀 진행
                a_hp = round(a_hp - (b_attack / a_defense * a_attribute_1 * a_attribute_2), 3)
                b_attack_num += 1
                print(pokemon2_name, '공격')
                print(pokemon1_name,' hp :', a_hp, '/', 'attack count : ', a_attack_num)
                print(pokemon2_name,' hp :', b_hp, '/', 'attack count : ', b_attack_num)

                if a_hp <= 0 or b_hp <= 0:
                    if a_hp <= 0:
                        return print(pokemon2_name, ' win!')
                        break
                    elif b_hp <= 0:
                        return print(pokemon1_name, ' win!')
                        break
                    else:
                        continue

                #attack 3회 후 sp_attack. 반복
                if b_attack_num != 0 and b_attack_num %3 == 0:
                    a_hp = round(a_hp - (b_sp_attack / a_sp_defense * a_attribute_1 * a_attribute_2), 3)
                    print(pokemon2_name, '스페셜 어택!')
                    print(pokemon1_name,' hp :', a_hp, '/', 'attack count : ', a_attack_num)
                    print(pokemon2_name,' hp :', b_hp, '/', 'attack count : ', b_attack_num)

                    if a_hp <= 0 or b_hp <= 0:
                        if a_hp <= 0:
                            return print(pokemon2_name, ' win!')
                            break
                        elif b_hp <= 0:
                            return print(pokemon1_name, ' win!')
                            break
                        else:
                            continue

                b_hp = round(b_hp - (a_attack / b_defense * b_attribute_1 * b_attribute_2), 3)
                a_attack_num += 1
                print(pokemon1_name, '공격')
                print(pokemon1_name,' hp :', a_hp, '/', 'attack count : ', a_attack_num)
                print(pokemon2_name,' hp :', b_hp, '/', 'attack count : ', b_attack_num)

                if a_hp <= 0 or b_hp <= 0:
                    if a_hp <= 0:
                        return print(pokemon2_name, ' win!')
                        break
                    elif b_hp <= 0:
                        return print(pokemon1_name, ' win!')
                        break
                    else:
                        continue

                #attack 3회 후 sp_attack. 반복
                if a_attack_num != 0 and a_attack_num %3 == 0:
                    b_hp = round(b_hp - (a_sp_attack / b_sp_defense * b_attribute_1 * b_attribute_2), 3)
                    print(pokemon1_name, '스페셜 어택!')
                    print(pokemon1_name,' hp :', a_hp, '/', 'attack count : ', a_attack_num)
                    print(pokemon2_name,' hp :', b_hp, '/', 'attack count : ', b_attack_num)

                    if a_hp <= 0 or b_hp <= 0:
                        if a_hp <= 0:
                            return print(pokemon2_name, ' win!')
                            break
                        elif b_hp <= 0:
                            return print(pokemon1_name, ' win!')
                            break
                        else:
                            continue

# %%
#결과만 알려주는 버전


def battle_skip (pokemon1_name, pokemon2_name):
    print(pokemon1_name, 'VS', pokemon2_name)
    print(' ')
    #a = 포켓몬 1
    a_attack = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 18]
    a_defense = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 20]
    a_hp = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 21]
    a_sp_attack = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 23]
    a_sp_defense = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 24]
    a_speed = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 25]
    a_type1 = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 26]
    a_type2 = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 27]
    
    #b = 포켓몬 2
    b_attack = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 18]
    b_defense = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 20]
    b_hp = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 21]
    b_sp_attack = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 23]
    b_sp_defense = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 24]
    b_speed = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 25]
    b_type1 = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 26]
    b_type2 = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 27]
    
    
    
    # 스킬 타입 정하기. 최초 1회만 하면 됨. attribute
    #((a타입상성1 * b타입상성1) * (a타입상성1 *b 타입상성2))
    #((a타입상성2 * b타입상성1) * (a타입상성2 *b 타입상성2))
    #첫번째 타입은 필수, 두번째 타입이 없을 때는 1(첫번째 타입의 값에 영향을 주면 안됨)
    
    #포켓몬 1
    a_attribute_1 = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , pokemon_type[b_type1]]
    if b_type2 == 'None':
        a_attribute_2 = 1
    else:
        a_attribute_2 = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , pokemon_type[b_type2]]
        
    #포켓몬 2
    b_attribute_1 = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , pokemon_type[a_type1]]
    if a_type2 == 'None':
        b_attribute_2 = 1
    else:
        b_attribute_2 = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , pokemon_type[a_type2]]

    
        
    #포켓몬 1 선공일 때
    if a_speed > b_speed :
        a_attack_num = 0
        b_attack_num = 0

        #한 포켓몬의 체력이 0 이하가 될때까지 배틀 진행
        while a_hp >= 0 or b_hp >= 0:
            
            #순차적으로 배틀 진행 - 포켓몬 1 선공
            b_hp = round(b_hp - (a_attack / b_defense * b_attribute_1 * b_attribute_2))
            a_attack_num += 1
            
            if a_hp <= 0 or b_hp <= 0:
                    if a_hp <= 0:
                        return print(pokemon2_name, ' win!')
                        break
                    elif b_hp <= 0:
                        return print(pokemon1_name, ' win!')
                        break
                    else:
                        continue
            
            #attack 3회 후 sp_attack. 반복
            if a_attack_num != 0 and a_attack_num %3 == 0:
                b_hp = round(b_hp - (a_sp_attack / b_sp_defense * b_attribute_1 * b_attribute_2))
                
                if a_hp <= 0 or b_hp <= 0:
                    if a_hp <= 0:
                        return print(pokemon2_name, ' win!')
                        break
                    elif b_hp <= 0:
                        return print(pokemon1_name, ' win!')
                        break
                    else:
                        continue

            #포켓몬 2 후공
            a_hp = round(a_hp - (b_attack / a_defense * a_attribute_1 * a_attribute_2))
            b_attack_num += 1

            if a_hp <= 0 or b_hp <= 0:
                if a_hp <= 0:
                    return print(pokemon2_name, ' win!')
                    break
                elif b_hp <= 0:
                    return print(pokemon1_name, ' win!')
                    break
                else:
                    continue
            
            #attack 3회 후 sp_attack. 반복
            if b_attack_num != 0 and b_attack_num %3 == 0:
                a_hp = round(a_hp - (b_sp_attack / a_sp_defense * a_attribute_1 * a_attribute_2))
                
                if a_hp <= 0 or b_hp <= 0:
                    if a_hp <= 0:
                        return print(pokemon2_name, ' win!')
                        break
                    elif b_hp <= 0:
                        return print(pokemon1_name, ' win!')
                        break
                    else:
                        continue
                
            
        
    #포켓몬 2 선공일 때
    elif a_speed < b_speed :
        a_attack_num = 0
        b_attack_num = 0
        
        #한 포켓몬의 체력이 0 이하가 될때까지 배틀 진행
        while a_hp >= 0 or b_hp >= 0:
                
            #순차적으로 배틀 진행
            a_hp = round(a_hp - (b_attack / a_defense * a_attribute_1 * a_attribute_2))
            b_attack_num += 1

            if a_hp <= 0 or b_hp <= 0:
                if a_hp <= 0:
                    return print(pokemon2_name, ' win!')
                    break
                elif b_hp <= 0:
                    return print(pokemon1_name, ' win!')
                    break
                else:
                    continue
            
            #attack 3회 후 sp_attack. 반복
            if b_attack_num != 0 and b_attack_num %3 == 0:
                a_hp = round(a_hp - (b_sp_attack / a_sp_defense * a_attribute_1 * a_attribute_2))
                
                if a_hp <= 0 or b_hp <= 0:
                    if a_hp <= 0:
                        return print(pokemon2_name, ' win!')
                        break
                    elif b_hp <= 0:
                        return print(pokemon1_name, ' win!')
                        break
                    else:
                        continue

            b_hp = round(b_hp - (a_attack / b_defense * b_attribute_1 * b_attribute_2))
            a_attack_num += 1
            
            if a_hp <= 0 or b_hp <= 0:
                if a_hp <= 0:
                    return print(pokemon2_name, ' win!')
                    break
                elif b_hp <= 0:
                    return print(pokemon1_name, ' win!')
                    break
                else:
                    continue

            if a_attack_num != 0 and a_attack_num %3 == 0:
                b_hp = round(b_hp - (a_sp_attack / b_sp_defense * b_attribute_1 * b_attribute_2))
                
                if a_hp <= 0 or b_hp <= 0:
                    if a_hp <= 0:
                        return print(pokemon2_name, ' win!')
                        break
                    elif b_hp <= 0:
                        return print(pokemon1_name, ' win!')
                        break
                    else:
                        continue

                
        
            
    #포켓몬 1, 2 speed 같을 때 선공 정하기
    else:
        speed_random = random.sample(range(3), 2)
        a_speed = speed_random[0]
        b_speed = speed_random[1]

        #포켓몬 1이 더 빠를 때
        if a_speed > b_speed :
            a_attack_num = 0
            b_attack_num = 0

            #한 포켓몬의 체력이 0 이하가 될때까지 배틀 진행
            while a_hp >= 0 or b_hp >= 0:

                #순차적으로 배틀 진행
                b_hp = round(b_hp - (a_attack / b_defense * b_attribute_1 * b_attribute_2))
                a_attack_num += 1

                if a_hp <= 0 or b_hp <= 0:
                        if a_hp <= 0:
                            return print(pokemon2_name, ' win!')
                            break
                        elif b_hp <= 0:
                            return print(pokemon1_name, ' win!')
                            break
                        else:
                            continue

                #attack 3회 후 sp_attack. 반복
                if a_attack_num != 0 and a_attack_num %3 == 0:
                    b_hp = round(b_hp - (a_sp_attack / b_sp_defense * b_attribute_1 * b_attribute_2))

                    if a_hp <= 0 or b_hp <= 0:
                        if a_hp <= 0:
                            return print(pokemon2_name, ' win!')
                            break
                        elif b_hp <= 0:
                            return print(pokemon1_name, ' win!')
                            break
                        else:
                            continue

                a_hp = round(a_hp - (b_attack / a_defense * a_attribute_1 * a_attribute_2))
                b_attack_num += 1

                if a_hp <= 0 or b_hp <= 0:
                    if a_hp <= 0:
                        return print(pokemon2_name, ' win!')
                        break
                    elif b_hp <= 0:
                        return print(pokemon1_name, ' win!')
                        break
                    else:
                        continue

                #attack 3회 후 sp_attack. 반복
                if b_attack_num != 0 and b_attack_num %3 == 0:
                    a_hp = round(a_hp - (b_sp_attack / a_sp_defense * a_attribute_1 * a_attribute_2))

                    if a_hp <= 0 or b_hp <= 0:
                        if a_hp <= 0:
                            return print(pokemon2_name, ' win!')
                            break
                        elif b_hp <= 0:
                            return print(pokemon1_name, ' win!')
                            break
                        else:
                            continue
                
                
        #포켓몬 2가 더 빠를 때
        elif a_speed < b_speed :
            a_attack_num = 0
            b_attack_num = 0

            #한 포켓몬의 체력이 0 이하가 될때까지 배틀 진행
            while a_hp >= 0 or b_hp >= 0:

                #순차적으로 배틀 진행
                a_hp = round(a_hp - (b_attack / a_defense * a_attribute_1 * a_attribute_2))
                b_attack_num += 1

                if a_hp <= 0 or b_hp <= 0:
                    if a_hp <= 0:
                        return print(pokemon2_name, ' win!')
                        break
                    elif b_hp <= 0:
                        return print(pokemon1_name, ' win!')
                        break
                    else:
                        continue

                #attack 3회 후 sp_attack. 반복
                if b_attack_num != 0 and b_attack_num %3 == 0:
                    a_hp = round(a_hp - (b_sp_attack / a_sp_defense * a_attribute_1 * a_attribute_2))

                    if a_hp <= 0 or b_hp <= 0:
                        if a_hp <= 0:
                            return print(pokemon2_name, ' win!')
                            break
                        elif b_hp <= 0:
                            return print(pokemon1_name, ' win!')
                            break
                        else:
                            continue

                b_hp = round(b_hp - (a_attack / b_defense * b_attribute_1 * b_attribute_2))
                a_attack_num += 1

                if a_hp <= 0 or b_hp <= 0:
                    if a_hp <= 0:
                        return print(pokemon2_name, ' win!')
                        break
                    elif b_hp <= 0:
                        return print(pokemon1_name, ' win!')
                        break
                    else:
                        continue

                #attack 3회 후 sp_attack. 반복
                if a_attack_num != 0 and a_attack_num %3 == 0:
                    b_hp = round(b_hp - (a_sp_attack / b_sp_defense * b_attribute_1 * b_attribute_2))

                    if a_hp <= 0 or b_hp <= 0:
                        if a_hp <= 0:
                            return print(pokemon2_name, ' win!')
                            break
                        elif b_hp <= 0:
                            return print(pokemon1_name, ' win!')
                            break
                        else:
                            continue

# %%
battle_no_skip('Venusaur', 'Charizard')
# Out:
# Venusaur VS Charizard
#           fight!
# Charizard 선공!
# Charizard 공격
# Venusaur  hp : 76.618 / attack count :  0
# Charizard  hp : 78 / attack count :  1
# Venusaur 공격
# Venusaur  hp : 76.618 / attack count :  1
# Charizard  hp : 77.679 / attack count :  1
# Charizard 공격
# Venusaur  hp : 73.236 / attack count :  1
# Charizard  hp : 77.679 / attack count :  2
# Venusaur 공격
# Venusaur  hp : 73.236 / attack count :  2
# Charizard  hp : 77.358 / attack count :  2
# Charizard 공격
# Venusaur  hp : 69.854 / attack count :  2
# Charizard  hp : 77.358 / attack count :  3
# Charizard 스페셜 어택!
# Venusaur  hp : 64.554 / attack count :  2
# Charizard  hp : 77.358 / attack count :  3
# Venusaur 공격
# Venusaur  hp : 64.554 / attack count :  3
# Charizard  hp : 77.037 / attack count :  3
# Venusaur 스페셜 어택!
# Venusaur  hp : 64.554 / attack count :  3
# Charizard  hp : 76.772 / attack count :  3
# Charizard 공격
# Venusaur  hp : 61.172 / attack count :  3
# Charizard  hp : 76.772 / attack count :  4
# ...

# %%
battle_skip('Venusaur', 'Charizard')
# Out:
# Venusaur VS Charizard
#
# Charizard  win!

# %%
battle_skip(pokemon.sample(n = 2).iat[0,22], pokemon.sample(n = 2).iat[1,22])
# Out:
# Woobat VS Monferno
#
# Woobat  win!

# %%
battle_no_skip(pokemon.sample(n = 2).iat[0,22], pokemon.sample(n = 2).iat[1,22])
# Out:
# Metapod VS Garbodor
#           fight!
# Garbodor 선공!
# Garbodor 공격
# Metapod  hp : 48.273 / attack count :  0
# Garbodor  hp : 80 / attack count :  1
# Metapod 공격
# Metapod  hp : 48.273 / attack count :  1
# Garbodor  hp : 79.878 / attack count :  1
# Garbodor 공격
# Metapod  hp : 46.546 / attack count :  1
# Garbodor  hp : 79.878 / attack count :  2
# Metapod 공격
# Metapod  hp : 46.546 / attack count :  2
# Garbodor  hp : 79.756 / attack count :  2
# Garbodor 공격
# Metapod  hp : 44.819 / attack count :  2
# Garbodor  hp : 79.756 / attack count :  3
# Garbodor 스페셜 어택!
# Metapod  hp : 42.419 / attack count :  2
# Garbodor  hp : 79.756 / attack count :  3
# Metapod 공격
# Metapod  hp : 42.419 / attack count :  3
# Garbodor  hp : 79.634 / attack count :  3
# Metapod 스페셜 어택!
# Metapod  hp : 42.419 / attack count :  3
# Garbodor  hp : 79.482 / attack count :  3
# Garbodor 공격
# Metapod  hp : 40.692 / attack count :  3
# Garbodor  hp : 79.482 / attack count :  4
# Metapod 공격
# ...

# %%
#승패 결과 기록용 데이터프레임
battle_result = pd.DataFrame(columns = ['win', 'lose'])
battle_result
# Out:
# Empty DataFrame
# Columns: [win, lose]
# Index: []

# %%
from itertools import combinations

# %%
list(combinations(list(pokemon['name']), 2))
# Out:
# [('Bulbasaur', 'Ivysaur'),
#  ('Bulbasaur', 'Venusaur'),
#  ('Bulbasaur', 'Charmander'),
#  ('Bulbasaur', 'Charmeleon'),
#  ('Bulbasaur', 'Charizard'),
#  ('Bulbasaur', 'Squirtle'),
#  ('Bulbasaur', 'Wartortle'),
#  ('Bulbasaur', 'Blastoise'),
#  ('Bulbasaur', 'Caterpie'),
#  ('Bulbasaur', 'Metapod'),
#  ('Bulbasaur', 'Butterfree'),
#  ('Bulbasaur', 'Weedle'),
#  ('Bulbasaur', 'Kakuna'),
#  ('Bulbasaur', 'Beedrill'),
#  ('Bulbasaur', 'Pidgey'),
#  ('Bulbasaur', 'Pidgeotto'),
#  ('Bulbasaur', 'Pidgeot'),
#  ('Bulbasaur', 'Rattata'),
#  ('Bulbasaur', 'Raticate'),
#  ('Bulbasaur', 'Spearow'),
#  ('Bulbasaur', 'Fearow'),
#  ('Bulbasaur', 'Ekans'),
#  ('Bulbasaur', 'Arbok'),
#  ('Bulbasaur', 'Pikachu'),
#  ('Bulbasaur', 'Raichu'),
#  ('Bulbasaur', 'Sandshrew'),
#  ('Bulbasaur', 'Sandslash'),
#  ('Bulbasaur', 'Nidoran_x'),
#  ('Bulbasaur', 'Nidorina'),
#  ('Bulbasaur', 'Nidoqueen'),
#  ('Bulbasaur', 'Nidoran_y'),
#  ('Bulbasaur', 'Nidorino'),
#  ('Bulbasaur', 'Nidoking'),
# ...

# %%
list(combinations(list(pokemon['name']), 2))[0][0]
# Out:
# 'Bulbasaur'

# %%
len(list(combinations(list(pokemon['name']), 2)))
# Out:
# 320400

# %%
def function_test(a, b):
    a = a
    b = b
    
    return [a, b]

# %%
function_test('Venusaur', 'Charizard')
# Out:
# ['Venusaur', 'Charizard']

# %%
data = pd.DataFrame(columns = ['win', 'lose', 'draw_a', 'draw_b'])

# %%
data
# Out:
# Empty DataFrame
# Columns: [win, lose, draw_a, draw_b]
# Index: []

# %%
def function_test_2(a, b):
    function_test(a, b)
    
    data.loc[len(data)] = [a,b, 'none', 'none']

# %%
function_test_2('Venusaur', 'Charizard')

# %%
data
# Out:
#         win       lose draw_a draw_b
# 0  Venusaur  Charizard   none   none

# %% [markdown]
# # 길고 반복되는 부분 함수로 만들기

# %% [markdown]
# ## 1. 포켓몬 1 선공( a_speed > b_speed )

# %%
def pokemon_1_first_attack(pokemon1_name, a_hp, a_attack, a_defense, a_sp_attack, a_sp_defense, a_attribute_1, a_attribute_2, pokemon2_name, b_hp, b_attack, b_defense, b_sp_attack, b_sp_defense, b_attribute_1, b_attribute_2):
    a_attack_num = 0
    b_attack_num = 0

    #한 포켓몬의 체력이 0 이하가 될때까지 배틀 진행
    while a_hp >= 0 or b_hp >= 0:

        #순차적으로 배틀 진행 - 포켓몬 1 선공
        b_hp = b_hp - (a_attack / b_defense * b_attribute_1 * b_attribute_2)
        a_attack_num += 1

        if a_hp <= 0 or b_hp <= 0:
            if a_hp <= 0:
                battle_result.loc[len(battle_result)] = [pokemon2_name, pokemon1_name, 'none', 'none']
                break
            elif b_hp <= 0:
                battle_result.loc[len(battle_result)] = [pokemon1_name, pokemon2_name, 'none', 'none']
                break
            else:
                continue

        #attack 3회 후 sp_attack. 반복
        if a_attack_num != 0 and a_attack_num %3 == 0:
            b_hp = b_hp - (a_sp_attack / b_sp_defense * b_attribute_1 * b_attribute_2)

        if a_hp <= 0 or b_hp <= 0:
            if a_hp <= 0:
                battle_result.loc[len(battle_result)] = [pokemon2_name, pokemon1_name, 'none', 'none']
                break
            elif b_hp <= 0:
                battle_result.loc[len(battle_result)] = [pokemon1_name, pokemon2_name, 'none', 'none']
                break
            else:
                continue

        #포켓몬 2 후공
        a_hp = a_hp - (b_attack / a_defense * a_attribute_1 * a_attribute_2)
        b_attack_num += 1

        if a_hp <= 0 or b_hp <= 0:
            if a_hp <= 0:
                battle_result.loc[len(battle_result)] = [pokemon2_name, pokemon1_name, 'none', 'none']
                break
            elif b_hp <= 0:
                battle_result.loc[len(battle_result)] = [pokemon1_name, pokemon2_name, 'none', 'none']
                break
            else:
                continue

        #attack 3회 후 sp_attack. 반복
        if b_attack_num != 0 and b_attack_num %3 == 0:
            a_hp = a_hp - (b_sp_attack / a_sp_defense * a_attribute_1 * a_attribute_2)

            if a_hp <= 0 or b_hp <= 0:
                if a_hp <= 0:
                    battle_result.loc[len(battle_result)] = [pokemon2_name, pokemon1_name, 'none', 'none']
                    break
                elif b_hp <= 0:
                    battle_result.loc[len(battle_result)] = [pokemon1_name, pokemon2_name, 'none', 'none']
                    break
                else:
                    continue

# %% [markdown]
# ## 2. 포켓몬 2 선공( b_speed > a_speed )

# %%
def pokemon_2_first_attack(pokemon1_name, a_hp, a_attack, a_defense, a_sp_attack, a_sp_defense, a_attribute_1, a_attribute_2, pokemon2_name, b_hp, b_attack, b_defense, b_sp_attack, b_sp_defense, b_attribute_1, b_attribute_2):
    a_attack_num = 0
    b_attack_num = 0

    #한 포켓몬의 체력이 0 이하가 될때까지 배틀 진행
    while a_hp >= 0 or b_hp >= 0:

        #순차적으로 배틀 진행
        a_hp = a_hp - (b_attack / a_defense * a_attribute_1 * a_attribute_2)
        b_attack_num += 1

        if a_hp <= 0 or b_hp <= 0:
            if a_hp <= 0:
                battle_result.loc[len(battle_result)] = [pokemon2_name, pokemon1_name, 'none', 'none']
                break
            elif b_hp <= 0:
                battle_result.loc[len(battle_result)] = [pokemon1_name, pokemon2_name, 'none', 'none']
                break
            else:
                continue

        #attack 3회 후 sp_attack. 반복
        if b_attack_num != 0 and b_attack_num %3 == 0:
            a_hp = a_hp - (b_sp_attack / a_sp_defense * a_attribute_1 * a_attribute_2)

            if a_hp <= 0 or b_hp <= 0:
                if a_hp <= 0:
                    battle_result.loc[len(battle_result)] = [pokemon2_name, pokemon1_name, 'none', 'none']
                    break
                elif b_hp <= 0:
                    battle_result.loc[len(battle_result)] = [pokemon1_name, pokemon2_name, 'none', 'none']
                    break
                else:
                    continue

        b_hp = b_hp - (a_attack / b_defense * b_attribute_1 * b_attribute_2)
        a_attack_num += 1

        if a_hp <= 0 or b_hp <= 0:
            if a_hp <= 0:
                battle_result.loc[len(battle_result)] = [pokemon2_name, pokemon1_name, 'none', 'none']
                break
            elif b_hp <= 0:
                battle_result.loc[len(battle_result)] = [pokemon1_name, pokemon2_name, 'none', 'none']
                break
            else:
                continue

        if a_attack_num != 0 and a_attack_num %3 == 0:
            b_hp = b_hp - (a_sp_attack / b_sp_defense * b_attribute_1 * b_attribute_2)

            if a_hp <= 0 or b_hp <= 0:
                if a_hp <= 0:
                    battle_result.loc[len(battle_result)] = [pokemon2_name, pokemon1_name, 'none', 'none']
                    break
                elif b_hp <= 0:
                    battle_result.loc[len(battle_result)] = [pokemon1_name, pokemon2_name, 'none', 'none']
                    break
                else:
                    continue

# %% [markdown]
# # 함수 결합하라

# %%
#데이터테이블에 승패를 기록함

def battle_record (pokemon1_name, pokemon2_name):
    
    #a = 포켓몬 1
    a_attack = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 18]
    a_defense = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 20]
    a_hp = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 21]
    a_sp_attack = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 23]
    a_sp_defense = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 24]
    a_speed = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 25]
    a_type1 = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 26]
    a_type2 = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , 27]
    
    #b = 포켓몬 2
    b_attack = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 18]
    b_defense = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 20]
    b_hp = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 21]
    b_sp_attack = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 23]
    b_sp_defense = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 24]
    b_speed = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 25]
    b_type1 = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 26]
    b_type2 = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , 27]
    
    
    
    # 스킬 타입 정하기. 최초 1회만 하면 됨. attribute
    #((a타입상성1 * b타입상성1) * (a타입상성1 *b 타입상성2))
    #((a타입상성2 * b타입상성1) * (a타입상성2 *b 타입상성2))
    #첫번째 타입은 필수, 두번째 타입이 없을 때는 1(첫번째 타입의 값에 영향을 주면 안됨)
    
    #포켓몬 1
    a_attribute_1 = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , pokemon_type[b_type1]]
    if b_type2 == 'None':
        a_attribute_2 = 1
    else:
        a_attribute_2 = pokemon.iat[pokemon[pokemon['name'] == pokemon1_name].index[0] -1 , pokemon_type[b_type2]]
        
    #포켓몬 2
    b_attribute_1 = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , pokemon_type[a_type1]]
    if a_type2 == 'None':
        b_attribute_2 = 1
    else:
        b_attribute_2 = pokemon.iat[pokemon[pokemon['name'] == pokemon2_name].index[0] -1 , pokemon_type[a_type2]]

        
        
    # attribute 변수가 0일 때 무승부 기록
    # a, b 둘 다 변수 둘 중 하나가 0일 때 비김
    if (a_attribute_1 == 0 or a_attribute_2 == 0) and (b_attribute_1 == 0 or b_attribute_2 == 0):
        battle_result.loc[len(battle_result)] = ['none', 'none', pokemon1_name, pokemon2_name]
        return
    
    # a 포켓몬(첫번째 입력 포켓몬)의 attribute가 둘 중 하나라도 0일때, b 가 자동 이김
    if (a_attribute_1 == 0 or a_attribute_2 == 0) and (b_attribute_1 != 0 and b_attribute_2 != 0):
        battle_result.loc[len(battle_result)] = [pokemon2_name, pokemon1_name, 'none', 'none']
        return

    # b 포켓몬(첫번째 입력 포켓몬)의 attribute가 둘 중 하나라도 0일때, a 가 자동 이김
    if (a_attribute_1 != 0 and a_attribute_2 != 0) and (b_attribute_1 == 0 or b_attribute_2 == 0):
        battle_result.loc[len(battle_result)] = [pokemon1_name, pokemon2_name, 'none', 'none']
        return

    
    
        
    #포켓몬 1 선공일 때
    if a_speed > b_speed :
        pokemon_1_first_attack(pokemon1_name, a_hp, a_attack, a_defense, a_sp_attack, a_sp_defense, a_attribute_1, a_attribute_2, pokemon2_name, b_hp, b_attack, b_defense, b_sp_attack, b_sp_defense, b_attribute_1, b_attribute_2)
               
            
        
    #포켓몬 2 선공일 때
    elif a_speed < b_speed :
        pokemon_2_first_attack(pokemon1_name, a_hp, a_attack, a_defense, a_sp_attack, a_sp_defense, a_attribute_1, a_attribute_2, pokemon2_name, b_hp, b_attack, b_defense, b_sp_attack, b_sp_defense, b_attribute_1, b_attribute_2)

        
                
            
    #포켓몬 1, 2 speed 같을 때 선공 정하기
    else:
        speed_random = random.sample(range(3), 2)
        a_speed = speed_random[0]
        b_speed = speed_random[1]

        #포켓몬 1이 더 빠를 때
        if a_speed > b_speed :
            pokemon_1_first_attack(pokemon1_name, a_hp, a_attack, a_defense, a_sp_attack, a_sp_defense, a_attribute_1, a_attribute_2, pokemon2_name, b_hp, b_attack, b_defense, b_sp_attack, b_sp_defense, b_attribute_1, b_attribute_2)

                
        #포켓몬 2가 더 빠를 때
        elif a_speed < b_speed :
            pokemon_2_first_attack(pokemon1_name, a_hp, a_attack, a_defense, a_sp_attack, a_sp_defense, a_attribute_1, a_attribute_2, pokemon2_name, b_hp, b_attack, b_defense, b_sp_attack, b_sp_defense, b_attribute_1, b_attribute_2)

# %%
battle_result = pd.DataFrame(columns = ['win', 'lose', 'draw_a', 'draw_b'])
battle_result
# Out:
# Empty DataFrame
# Columns: [win, lose, draw_a, draw_b]
# Index: []

# %%
battle_record(list(combinations(list(pokemon['name']), 2))[4][0], list(combinations(list(pokemon['name']), 2))[4][1])

# %%
battle_result
# Out:
#          win       lose draw_a draw_b
# 0  Charizard  Bulbasaur   none   none

# %%
battle_result.drop(0)
# Out:
# Empty DataFrame
# Columns: [win, lose, draw_a, draw_b]
# Index: []

# %%
# 위 함수를 모든 포켓몬 조합에 적용하기

#테스트
count = 0
for i in range(10):
    battle_record(list(combinations(list(pokemon['name']), 2))[count][0], list(combinations(list(pokemon['name']), 2))[count][1])
    count += 1

    print(battle_result)
# Out:
#          win       lose draw_a draw_b
# 0  Charizard  Bulbasaur   none   none
# 1    Ivysaur  Bulbasaur   none   none
#          win       lose draw_a draw_b
# 0  Charizard  Bulbasaur   none   none
# 1    Ivysaur  Bulbasaur   none   none
# 2   Venusaur  Bulbasaur   none   none
#           win       lose draw_a draw_b
# 0   Charizard  Bulbasaur   none   none
# 1     Ivysaur  Bulbasaur   none   none
# 2    Venusaur  Bulbasaur   none   none
# 3  Charmander  Bulbasaur   none   none
#           win       lose draw_a draw_b
# 0   Charizard  Bulbasaur   none   none
# 1     Ivysaur  Bulbasaur   none   none
# 2    Venusaur  Bulbasaur   none   none
# 3  Charmander  Bulbasaur   none   none
# 4  Charmeleon  Bulbasaur   none   none
#           win       lose draw_a draw_b
# 0   Charizard  Bulbasaur   none   none
# 1     Ivysaur  Bulbasaur   none   none
# 2    Venusaur  Bulbasaur   none   none
# 3  Charmander  Bulbasaur   none   none
# 4  Charmeleon  Bulbasaur   none   none
# ...

# %%
battle_result
# Out:
#            win       lose draw_a draw_b
# 0    Charizard  Bulbasaur   none   none
# 1      Ivysaur  Bulbasaur   none   none
# 2     Venusaur  Bulbasaur   none   none
# 3   Charmander  Bulbasaur   none   none
# 4   Charmeleon  Bulbasaur   none   none
# 5    Charizard  Bulbasaur   none   none
# 6    Bulbasaur   Squirtle   none   none
# 7    Bulbasaur  Wartortle   none   none
# 8    Blastoise  Bulbasaur   none   none
# 9    Bulbasaur   Caterpie   none   none
# 10   Bulbasaur    Metapod   none   none

# %%
battle_result = pd.DataFrame(columns = ['win', 'lose', 'draw_a', 'draw_b'])
battle_result
# Out:
# Empty DataFrame
# Columns: [win, lose, draw_a, draw_b]
# Index: []

# %%
len(list(combinations(list(pokemon['name']), 2)))
# Out:
# 320400

# %%
#배틀 함수를 모든 포켓몬 조합에 적용하기

#실전
count = 0
for i in range(len(list(combinations(list(pokemon['name']), 2)))):
    battle_record(list(combinations(list(pokemon['name']), 2))[count][0], list(combinations(list(pokemon['name']), 2))[count][1])
    count += 1
    
    if count % 100 == 0:
        print(count,'만큼 진행했어')
        
    if i == 320399:
        print('끝나써!!')
# Out:
# 100 만큼 진행했어
# 200 만큼 진행했어
# 300 만큼 진행했어
# 400 만큼 진행했어
# 500 만큼 진행했어
# 600 만큼 진행했어
# 700 만큼 진행했어
# 800 만큼 진행했어
# 900 만큼 진행했어
# 1000 만큼 진행했어
# 1100 만큼 진행했어
# 1200 만큼 진행했어
# 1300 만큼 진행했어
# 1400 만큼 진행했어
# 1500 만큼 진행했어
# 1600 만큼 진행했어
# 1700 만큼 진행했어
# 1800 만큼 진행했어
# 1900 만큼 진행했어
# 2000 만큼 진행했어
# 2100 만큼 진행했어
# 2200 만큼 진행했어
# 2300 만큼 진행했어
# 2400 만큼 진행했어
# 2500 만큼 진행했어
# 2600 만큼 진행했어
# 2700 만큼 진행했어
# 2800 만큼 진행했어
# 2900 만큼 진행했어
# 3000 만큼 진행했어
# 3100 만큼 진행했어
# 3200 만큼 진행했어
# 3300 만큼 진행했어
# 3400 만큼 진행했어
# 3500 만큼 진행했어
# 3600 만큼 진행했어
# 3700 만큼 진행했어
# 3800 만큼 진행했어
# 3900 만큼 진행했어
# 4000 만큼 진행했어
# 4100 만큼 진행했어
# 4200 만큼 진행했어
# 4300 만큼 진행했어
# 4400 만큼 진행했어
# 4500 만큼 진행했어
# 4600 만큼 진행했어
# 4700 만큼 진행했어
# 4800 만큼 진행했어
# 4900 만큼 진행했어
# 5000 만큼 진행했어
# 5100 만큼 진행했어
# 5200 만큼 진행했어
# 5300 만큼 진행했어
# 5400 만큼 진행했어
# 5500 만큼 진행했어
# 5600 만큼 진행했어
# 5700 만큼 진행했어
# 5800 만큼 진행했어
# 5900 만큼 진행했어
# 6000 만큼 진행했어
# 6100 만큼 진행했어
# 6200 만큼 진행했어
# 6300 만큼 진행했어
# 6400 만큼 진행했어
# 6500 만큼 진행했어
# 6600 만큼 진행했어
# 6700 만큼 진행했어
# ...

# %%
battle_result.drop(index = 0, axis = 0)
# Out:
#                win       lose draw_a draw_b
# 1          Ivysaur  Bulbasaur   none   none
# 2         Venusaur  Bulbasaur   none   none
# 3       Charmander  Bulbasaur   none   none
# 4       Charmeleon  Bulbasaur   none   none
# 5        Charizard  Bulbasaur   none   none
# ...            ...        ...    ...    ...
# 320396     Kartana   Necrozma   none   none
# 320397     Kartana   Magearna   none   none
# 320398    Necrozma   Guzzlord   none   none
# 320399    Guzzlord   Magearna   none   none
# 320400    Magearna   Necrozma   none   none
#
# [320400 rows x 4 columns]

# %%
battle_result.to_csv("pokemon_battle_result.csv")

# %%
#쟈~ 이제 어떤 포켓몬이 가장 많이 이겼나 확인해볼까요오?
battle_result['win'].value_counts()
# Out:
# none        4770
# Zekrom       783
# Mewtwo       751
# Palkia       750
# Ampharos     747
#             ...
# Smeargle      19
# Magikarp       4
# Chansey        4
# Feebas         2
# Shedinja       1
# Name: win, Length: 801, dtype: int64

# %%
battle_result['win'].value_counts().head(11)
# 호오.. 흥미롭군요...
# Out:
# none        4770
# Zekrom       783
# Mewtwo       751
# Palkia       750
# Ampharos     747
# Kyogre       742
# Zygarde      740
# Latios       736
# Slaking      732
# Latias       732
# Kyurem       728
# Name: win, dtype: int64

# %%
battle_result['lose'].value_counts().tail(10)
# Out:
# Latios       64
# Kyogre       58
# Zygarde      55
# Ampharos     53
# Palkia       50
# Mewtwo       49
# Regigigas    42
# Arceus       35
# Slaking      27
# Zekrom       17
# Name: lose, dtype: int64

# %%
783/800*100
# Out:
# 97.875

# %% [markdown]
# 길고 긴 여정이었다.
# ## * 가장 강한 포켓몬 1가지는?
# ### 한정된 자원으로 1가지 포켓몬만 키울 수 있다면...
#
# 포켓몬은 총 801마리, 1 마리 당 800번의 배틀 중 783회(97.875%)를 이긴 **Zekrom(제크로무)**를 선택하는 것이 가장 많이 이길 수 있을 것이다.</br>
# 800전 783승 0무 17패
